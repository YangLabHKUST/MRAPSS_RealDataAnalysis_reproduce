# %% [markdown]
# # Format GWAS summary-level data

# %%
library(MRAPSS)
library(readr)

# %%
## 1. AD
AD_raw <- readr::read_delim("./GWAS_26and5_raw/AD", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
AD = format_data(AD_raw,
                 snp_col = "MarkerName",
                 b_col = "Beta",
                 se_col = "SE",
                 A1_col = "Effect_allele",
                 A2_col = "Non_Effect_allele",
                 p_col = "Pvalue",
                 n = 54162)

write.table(AD, "./GWAS_26and5_formatted/AD", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("AD","AD_raw"))
# Out:
# Rows: 7055881 Columns: 8
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): MarkerName, Effect_allele, Non_Effect_allele
# dbl (5): Chromosome, Position, Beta, SE, Pvalue
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 7055881 dat lines
#
# Remove ambiguous SNPs ..., remaining 6004428 SNPs.
#
# Remove SNPs in MHC region ..., remaining 5993962 SNPs.
#
# Remove duplicated SNPs ..., remaining 5993414 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1148529 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1148507 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1148507 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1148507 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1148507 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1148476 SNPs.
#
# The formatted data has 1148476 dat lines.

# %%
## 2. Alcohol
Alcohol_raw <- readr::read_delim("./GWAS_26and5_raw/Alcohol", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Alcohol = format_data(Alcohol_raw,
                      snp_col = "MarkerName",
                      b_col = "Beta",
                      se_col = "SE",
                      freq_col = "EAF_A1",
                      A1_col = "A1",
                      A2_col = "A2",
                      p_col = "Pval",
                      n = 414343)

write.table(Alcohol, "./GWAS_26and5_formatted/Alcohol", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("Alcohol_raw","Alcohol"))
# Out:
# Rows: 11514936 Columns: 9
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): MarkerName, A1, A2
# dbl (6): CHR, POS, EAF_A1, Beta, SE, Pval
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 11514936 dat lines
#
# Remove ambiguous SNPs ..., remaining 9791370 SNPs.
#
# Remove SNPs in MHC region ..., remaining 9742990 SNPs.
#
# Remove duplicated SNPs ..., remaining 9661810 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1198814 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1198811 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1084534 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1084534 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1084534 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1084534 SNPs.
#
# The formatted data has 1084534 dat lines.

# %%
## 3. Angina
Angina_raw <- readr::read_delim("./GWAS_26and5_raw/Angina", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Angina = format_data(Angina_raw,
                     snp_col = "SNPID_UKB",
                     or_col = "OR",
                     se_col = "SE",
                     freq_col = "MAF_UKB",
                     A1_col = "A1",
                     A2_col = "A2",
                     p_col = "P",
                     n_col = "NMISS",
                     info_col = "INFO_UKB")

write.table(Angina, "./GWAS_26and5_formatted/Angina", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("Angina_raw","Angina"))
# Out:
# Rows: 10321705 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10321705 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10321675 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8761299 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8711402 SNPs.
#
# Remove duplicated SNPs ..., remaining 8711402 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161107 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1160815 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037824 SNPs.
#
# The formatted data has 1037824 dat lines.

# %%
## 4. Anorexia
Anorexia_raw <- readr::read_delim("./GWAS_26and5_raw/Anorexia", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Anorexia = format_data(Anorexia_raw,
                       snp_col = "ID",
                       b_col = "BETA",
                       se_col = "SE",
                       A1_col = "ALT",
                       A2_col = "REF",
                       p_col = "PVAL",
                       ncase_col  = "NCAS",
                       ncontrol_col = "NCON",
                       info_col = "IMPINFO")

write.table(Anorexia, "./GWAS_26and5_formatted/Anorexia", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Anorexia_raw","Anorexia"))
# Out:
# Rows: 8219102 Columns: 14
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (4): ID, REF, ALT, DIRE
# dbl (10): CHROM, POS, BETA, SE, PVAL, NGT, IMPINFO, NEFFDIV2, NCAS, NCON
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 8219102 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 5880021 SNPs.
#
# effect allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 5880020 SNPs.
#
# the other allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 5880019 SNPs.
#
# Remove ambiguous SNPs ..., remaining 5064495 SNPs.
#
# Remove SNPs in MHC region ..., remaining 5033100 SNPs.
#
# Remove duplicated SNPs ..., remaining 4986546 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 922421 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 922420 SNPs.
#
# Generating sample size from ncase and ncontrol
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 922420 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 922420 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 910374 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 910374 SNPs.
#
# The formatted data has 910374 dat lines.

# %%
## 5. ASD
ASD_raw <- readr::read_delim("./GWAS_26and5_raw/ASD", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

ASD = format_data(ASD_raw,
                  snp_col = "snp",
                  b_col = "b",
                  se_col = "StdErr",
                  freq_col = "freq_A1",
                  A1_col = "A1",
                  A2_col = "A2",
                  p_col = "p",
                  n_col = "N")

write.table(ASD, "./GWAS_26and5_formatted/ASD", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("ASD_raw","ASD"))
# Out:
# Rows: 6517324 Columns: 15
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (4): snp, A1, A2, direction
# dbl (11): chr, bp_hg19, or, tor_l95, or_u95, b, se, p, freq_A1, info, N
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 6517324 dat lines
#
# effect allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 6517323 SNPs.
#
# the other allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 6517322 SNPs.
#
# Remove ambiguous SNPs ..., remaining 5593524 SNPs.
#
# Remove SNPs in MHC region ..., remaining 5585718 SNPs.
#
# Remove duplicated SNPs ..., remaining 5585718 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1093312 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1079411 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1079411 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1076873 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1076873 SNPs.
#
# The formatted data has 1076873 dat lines.

# %%
## 6. BMI
BMI_raw <- readr::read_delim("./GWAS_26and5_raw/BMI", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

BMI = format_data(BMI_raw,
                  snp_col = "SNPID_UKB",
                  b_col = "BETA",
                  se_col = "SE",
                  freq_col = "MAF_UKB",
                  A1_col = "A1",
                  A2_col = "A2",
                  p_col = "P",
                  n_col = "NMISS",
                  info_col = "INFO_UKB")

write.table(BMI, "./GWAS_26and5_formatted/BMI", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("BMI_raw","BMI"))
# Out:
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, BETA, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UK...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037799 SNPs.
#
# The formatted data has 1037799 dat lines.

# %%
## 7. CAD
CAD_raw <- readr::read_delim("./GWAS_26and5_raw/CAD", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

CAD = format_data(CAD_raw,
                  snp_col = "markername",
                  b_col = "beta",
                  se_col = "se",
                  freq_col = "effect_allele_freq",
                  A1_col = "effect_allele",
                  A2_col = "noneffect_allele",
                  p_col = "p_dgc",
                  n = 184305)

write.table(CAD, "./GWAS_26and5_formatted/CAD", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("CAD_raw","CAD"))
# Out:
# Rows: 9455778 Columns: 13
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): markername, effect_allele, noneffect_allele, model
# dbl (9): chr, bp_hg19, effect_allele_freq, median_info, beta, se_dgc, p_dgc,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 9455778 dat lines
#
# effect allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 9455777 SNPs.
#
# the other allele column has some values that are not A/C/T/G. Remove these SNPs..., remaining 9455776 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8123051 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8109390 SNPs.
#
# Remove duplicated SNPs ..., remaining 8109390 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1192337 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1112984 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1112984 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1112984 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1112977 SNPs.
#
# The formatted data has 1112977 dat lines.

# %%
## 8. CD (Crohn Disease)
CD_raw <- readr::read_delim("./GWAS_26and5_raw/CD_rsid", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

CD = format_data(CD_raw,
                 snp_col = "rsid",
                 b_col = "Effect",
                 se_col = "StdErr",
                 freq_col = "freq",
                 A1_col = "Allele1",
                 A2_col = "Allele2",
                 p_col = "P.value",
                 n = 40266)

write.table(CD, "./GWAS_26and5_formatted/CD", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("CD_raw","CD"))
# Out:
# Rows: 8533371 Columns: 19
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (6): rsid, a1, a2, Allele1, Allele2, Direction
# dbl (13): chr, bp, Effect, StdErr, P.value, HetISq, HetChiSq, HetDf, HetPVal...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 8533371 dat lines
#
# Remove ambiguous SNPs ..., remaining 7268752 SNPs.
#
# Remove SNPs in MHC region ..., remaining 7234063 SNPs.
#
# Remove duplicated SNPs ..., remaining 7230277 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1150096 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1150086 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1150086 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1150086 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1150086 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1149704 SNPs.
#
# The formatted data has 1149704 dat lines.

# %%
## 9. DaytimeSleepiness
dat_raw <- readr::read_delim("./GWAS_26and5_raw/DaytimeSleepiness", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

dat = format_data(dat_raw,
                  snp_col = "SNP",
                  b_col = "BETA",
                  se_col = "SE",
                  freq_col = "A1FREQ",
                  A1_col = "ALLELE1",
                  A2_col = "ALLELE0",
                  info_col = "INFO",
                  p_col = "P",
                  n = 452071)

write.table(dat, "./GWAS_26and5_formatted/Daytime_Sleepiness",  sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("dat_raw","dat"))
# Out:
# Rows: 14661601 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, ALLELE1, ALLELE0
# dbl (7): CHR, BP, A1FREQ, INFO, BETA, SE, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 14661601 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10903657 SNPs.
#
# Remove ambiguous SNPs ..., remaining 9250294 SNPs.
#
# Remove SNPs in MHC region ..., remaining 9202639 SNPs.
#
# Remove duplicated SNPs ..., remaining 9196675 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1198480 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1198465 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1065141 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1065141 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1065141 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1065141 SNPs.
#
# The formatted data has 1065141 dat lines.

# %%
## 10. Depression
dat_raw <- readr::read_delim("./GWAS_26and5_raw/Depression", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

dat = MRAPSS::format_data(dat_raw,
                          snp_col = "RSID",
                          z_col = "Z",
                          freq_col = "MAF_UKB",
                          A1_col = "A1",
                          A2_col = "A2",
                          p_col = "P",
                          n_col = "N",
                          info_col = "INFO_UKB")

write.table(dat, "./GWAS_26and5_formatted/Depression", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("dat_raw","dat"))
# Out:
# Rows: 10886529 Columns: 12
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): RSID, SNP, A1, A2
# dbl (8): CHR, POS, EAF_UKB, MAF_UKB, Z, P, N, INFO_UKB
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10886529 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10847393 SNPs.
#
# Remove ambiguous SNPs ..., remaining 9204753 SNPs.
#
# Remove SNPs in MHC region ..., remaining 9152908 SNPs.
#
# Remove duplicated SNPs ..., remaining 9152468 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161303 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161185 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1026902 SNPs.
#
# Remove missing values, remaining 1026902 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1026744 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1026744 SNPs.
#
# The formatted data has 1026744 dat lines.

# %%
## 11-14. Hair_Black, Hair_Blonde, Hair_Dark_Brown, Hair_Light_Brown
for (trait in c("Hair_Black", "Hair_Blonde", "Hair_Dark_Brown", "Hair_Light_Brown")){
  
  dat_raw <- readr::read_delim(paste0("./GWAS_26and5_raw/", trait), delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
  
  dat = format_data(dat_raw,
                    snp_col = "SNPID_UKB",
                    or_col = "OR",
                    se_col = "SE",
                    freq_col = "MAF_UKB",
                    A1_col = "A1",
                    A2_col = "A2",
                    p_col = "P",
                    n_col = "NMISS",
                    info_col = "INFO_UKB")
  
  write.table(dat, paste0("./GWAS_26and5_formatted/", trait), sep="\t", quote = F, row.names = F, col.names = T)
  
  rm(list=c("dat_raw", "dat"))
  
}
# Out:
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037702 SNPs.
#
# The formatted data has 1037702 dat lines.
#
#
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037533 SNPs.
#
# The formatted data has 1037533 dat lines.
#
#
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037381 SNPs.
#
# The formatted data has 1037381 dat lines.
#
#
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037742 SNPs.
#
# The formatted data has 1037742 dat lines.

# %%
## 15. HBP (High Blood Pressure)

HBP_raw <- readr::read_delim("./GWAS_26and5_raw/HBP", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

HBP = MRAPSS::format_data(HBP_raw,
                          snp_col = "SNPID_UKB",
                          or_col = "OR",
                          se_col = "SE",
                          freq_col = "MAF_UKB",
                          A1_col = "A1",
                          A2_col = "A2",
                          p_col = "P",
                          n_col = "NMISS",
                          info_col = "INFO_UKB")

write.table(HBP, "./GWAS_26and5_formatted/HBP", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("HBP_raw", "HBP"))
# Out:
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037824 SNPs.
#
# The formatted data has 1037824 dat lines.

# %%
## 16. Height (GIANT)

Height_raw <- readr::read_delim("./GWAS_26and5_raw/Height_GIANT", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Height = format_data(Height_raw,
                     snp_col = "MarkerName",
                     b_col = "b",
                     se_col = "SE",
                     freq_col = "Freq.Allele1.HapMapCEU",
                     A1_col = "Allele1",
                     A2_col = "Allele2",
                     p_col = "p",
                     n_col = "N")

write.table(Height, "./GWAS_26and5_formatted/Height_GIANT", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("Height_raw","Height"))
# Out:
# Rows: 2550858 Columns: 8
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): MarkerName, Allele1, Allele2
# dbl (5): Freq.Allele1.HapMapCEU, b, SE, p, N
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 2550858 dat lines
#
# Remove ambiguous SNPs ..., remaining 2157027 SNPs.
#
# Remove SNPs in MHC region ..., remaining 2146505 SNPs.
#
# Remove duplicated SNPs ..., remaining 2146505 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1091208 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1091168 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 975060 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 975060 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 961179 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 961046 SNPs.
#
# The formatted data has 961046 dat lines.

# %%
## 17. Height (UKBB)

Height_UKB_raw <- readr::read_delim("./GWAS_26and5_raw/Height_UKB", "\t", escape_double = FALSE,
                                    trim_ws = TRUE, progress = F)

Height_UKB = format_data(Height_UKB_raw,
                         snp_col = "SNPID_UKB",
                         b_col = "BETA",
                         se_col = "SE",
                         freq_col = "MAF_UKB",
                         A1_col = "A1",
                         A2_col = "A2",
                         p_col = "P",
                         n_col = "NMISS",
                         info_col = "INFO_UKB")

write.table(Height_UKB, "./GWAS_26and5_formatted/Height_UKB", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Height_UKB_raw","Height_UKB"))
# Out:
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, BETA, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UK...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10599054 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10599018 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8995068 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8944044 SNPs.
#
# Remove duplicated SNPs ..., remaining 8944044 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161195 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037320 SNPs.
#
# The formatted data has 1037320 dat lines.

# %%
# 18. IBD (Inflammatory Bowel Disease)

IBD_raw <- readr::read_delim("./GWAS_26and5_raw/IBD_rsid", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

IBD = format_data(IBD_raw,
                  snp_col = "rsid",
                  b_col = "Effect",
                  se_col = "StdErr",
                  freq_col = "freq",
                  A1_col = "Allele1",
                  A2_col = "Allele2",
                  p_col = "P.value",
                  n = 59957)

write.table(IBD, "./GWAS_26and5_formatted/IBD", sep="\t", quote = F, row.names = F, col.names = T)

rm(list=c("IBD_raw","IBD"))
# Out:
# Rows: 8594484 Columns: 19
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (6): rsid, a1, a2, Allele1, Allele2, Direction
# dbl (13): chr, bp, Effect, StdErr, P.value, HetISq, HetChiSq, HetDf, HetPVal...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 8594484 dat lines
#
# Remove ambiguous SNPs ..., remaining 7321119 SNPs.
#
# Remove SNPs in MHC region ..., remaining 7286484 SNPs.
#
# Remove duplicated SNPs ..., remaining 7282558 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1150501 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1150491 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1150491 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1150491 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1150491 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1150157 SNPs.
#
# The formatted data has 1150157 dat lines.

# %%
## 19. Income

Income_raw <- readr::read_delim("./GWAS_26and5_raw/Income", " ", escape_double = FALSE, trim_ws = TRUE, progress = F)

Income = format_data(Income_raw,
                     snp_col = "SNP",
                     b_col = "Beta",
                     se_col = "Standard_Error_of_Beta",
                     A1_col = "Effect_Allele",
                     A2_col = "Non_effect_Allele",
                     p_col = "P",
                     n=286301)

write.table(Income, "./GWAS_26and5_formatted/Income", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Income_raw","Income"))
# Out:
# Rows: 18485882 Columns: 8
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: " "
# chr (3): SNP, Non_effect_Allele, Effect_Allele
# dbl (5): Chr, BPos, Beta, Standard_Error_of_Beta, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 18485882 dat lines
#
# Remove ambiguous SNPs ..., remaining 15709024 SNPs.
#
# Remove SNPs in MHC region ..., remaining 15648261 SNPs.
#
# Remove duplicated SNPs ..., remaining 15648261 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1208817 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1208814 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1208814 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1208814 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1208814 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1208814 SNPs.
#
# The formatted data has 1208814 dat lines.

# %%
## 20. Insomnia

Insomnia_raw <- readr::read_delim("./GWAS_26and5_raw/Insomnia", " ", escape_double = FALSE, trim_ws = TRUE, progress = F)

Insomnia = format_data(Insomnia_raw,
                       snp_col = "SNP",
                       b_col = "BETA_INSOMNIA",
                       se_col = "SE_INSOMNIA",
                       freq_col = "A1FREQ",
                       A1_col = "ALLELE1",
                       A2_col = "ALLELE0",
                       info_col = "INFO",
                       p_col = "P_INSOMNIA",
                       n = 453379)

write.table(Insomnia, "./GWAS_26and5_formatted/Insomnia", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Insomnia_raw","Insomnia"))
# Out:
# Rows: 14661601 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: " "
# chr (3): SNP, ALLELE1, ALLELE0
# dbl (7): CHR, BP, A1FREQ, INFO, BETA_INSOMNIA, SE_INSOMNIA, P_INSOMNIA
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 14661601 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10903657 SNPs.
#
# Remove ambiguous SNPs ..., remaining 9250294 SNPs.
#
# Remove SNPs in MHC region ..., remaining 9202639 SNPs.
#
# Remove duplicated SNPs ..., remaining 9196675 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1198480 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1198465 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1065149 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1065149 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1065149 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1065149 SNPs.
#
# The formatted data has 1065149 dat lines.

# %%
## 21. Intelligence

Intelligence_raw <- readr::read_delim("./GWAS_26and5_raw/Intelligence", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Intelligence = format_data(Intelligence_raw,
                           snp_col = "SNPID_UKB",
                           b_col = "BETA",
                           se_col = "SE",
                           freq_col = "MAF_UKB",
                           A1_col = "A1",
                           A2_col = "A2",
                           p_col = "P",
                           n_col = "NMISS",
                           info_col = "INFO_UKB")

write.table(Intelligence, "./GWAS_26and5_formatted/Intelligence", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Intelligence_raw","Intelligence"))
# Out:
# Rows: 9561902 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, BETA, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UK...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 9561902 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 9561873 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8119324 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8072530 SNPs.
#
# Remove duplicated SNPs ..., remaining 8072530 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1159117 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1158862 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037824 SNPs.
#
# The formatted data has 1037824 dat lines.

# %%
## 22. MDD
MDD_raw <- readr::read_delim("./GWAS_26and5_raw/MDD", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

MDD = MRAPSS::format_data(MDD_raw,
                          snp_col = "SNPID_UKB",
                          or_col = "OR",
                          se_col = "SE",
                          freq_col = "MAF_UKB",
                          A1_col = "A1",
                          A2_col = "A2",
                          p_col = "P",
                          n_col = "NMISS",
                          info_col = "INFO_UKB")

write.table(MDD, "./GWAS_26and5_formatted/MDD", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("MDD_raw","MDD"))
# Out:
# Rows: 10154467 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10154467 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10154437 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8620374 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8571258 SNPs.
#
# Remove duplicated SNPs ..., remaining 8571258 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1160811 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1160529 SNPs.
#
# infer b column from log(or)...
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037824 SNPs.
#
# The formatted data has 1037824 dat lines.

# %%
## 23. NEB
NEB_raw <- readr::read_delim("./GWAS_26and5_raw/NEB", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

NEB = MRAPSS::format_data(NEB_raw,
                          snp_col = "SNPID",
                          freq_col = "Freq_HapMap",
                          A1_col = "A1",
                          A2_col = "A2",
                          z_col = "Zscore",
                          p_col = "Pvalue",
                          n = 343072)

write.table(NEB, file = "./GWAS_26and5_formatted/NEB", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("NEB_raw","NEB"))
# Out:
# Rows: 2474037 Columns: 8
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNPID, A1, A2
# dbl (5): CHR, POS, Freq_HapMap, Zscore, Pvalue
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 2474037 dat lines
#
# Remove ambiguous SNPs ..., remaining 2092463 SNPs.
#
# Remove SNPs in MHC region ..., remaining 2089374 SNPs.
#
# Remove duplicated SNPs ..., remaining 2089374 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1078165 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 984184 SNPs.
#
# Remove missing values, remaining 984184 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 984184 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 984184 SNPs.
#
# The formatted data has 984184 dat lines.

# %%
## 24. Neuroticism
dat_raw <- readr::read_delim("./GWAS_26and5_raw/Neuroticism", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

dat = MRAPSS::format_data(dat_raw,
                          snp_col = "SNPID_UKB",
                          b_col = "BETA",
                          se_col = "SE",
                          freq_col = "MAF_UKB",
                          A1_col = "A1",
                          A2_col = "A2",
                          p_col = "P",
                          n_col = "NMISS",
                          info_col = "INFO_UKB")

write.table(dat, "./GWAS_26and5_formatted/Neuroticism", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("dat_raw","dat"))
# Out:
# Rows: 10399545 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, BETA, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UK...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10399545 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10399514 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8826898 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8776612 SNPs.
#
# Remove duplicated SNPs ..., remaining 8776612 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161220 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1160924 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037824 SNPs.
#
# The formatted data has 1037824 dat lines.

# %%
## 25. RA
RA_raw <- readr::read_delim("./GWAS_26and5_raw/RA", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

RA = format_data(RA_raw,
                  snp_col = "SNPID",
                  or_col = "OR(A1)",
                  A1_col = "A1",
                  A2_col = "A2",
                  p_col = "P-val",
                  n = 58284)

write.table(RA, "./GWAS_26and5_formatted/RA", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("RA_raw","RA"))
# Out:
# Rows: 8747962 Columns: 9
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNPID, A1, A2
# dbl (6): Chr, Position(hg19), OR(A1), OR_95%CIlow, OR_95%CIup, P-val
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 8747962 dat lines
#
# Remove ambiguous SNPs ..., remaining 7403737 SNPs.
#
# Remove SNPs in MHC region ..., remaining 7374270 SNPs.
#
# Remove duplicated SNPs ..., remaining 7374270 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1180154 SNPs.
#
# infer b column from log(or)...
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1180154 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1180154 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1180154 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1180049 SNPs.
#
# The formatted data has 1180049 dat lines.

# %%
# 26. SCZ

SCZ_raw <- readr::read_delim("./GWAS_26and5_raw/SCZ_rsid", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

SCZ = format_data(SCZ_raw,
                  snp_col = "rsid",
                  or_col = "OR",
                  se_col = "SE",
                  freq_col = "Freq.A1",
                  A1_col = "A1",
                  A2_col = "A2",
                  p_col = "P",
                  n=105318)

write.table(SCZ, "./GWAS_26and5_formatted/SCZ", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("SCZ_raw","SCZ"))
# Out:
# Rows: 7480977 Columns: 10
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): rsid, SNP, A1, A2
# dbl (6): Freq.A1, CHR, BP, OR, SE, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 7480977 dat lines
#
# Remove ambiguous SNPs ..., remaining 6341312 SNPs.
#
# Remove SNPs in MHC region ..., remaining 6315985 SNPs.
#
# Remove duplicated SNPs ..., remaining 6315867 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1145148 SNPs.
#
# infer b column from log(or)...
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1047566 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1047566 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1047566 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1047564 SNPs.
#
# The formatted data has 1047564 dat lines.

# %%
## 27. Smoking
Smoking_raw <- readr::read_delim("./GWAS_26and5_raw/Smoking", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

Smoking = format_data(Smoking_raw,
                      snp_col = "RSID",
                      b_col = "BETA",
                      se_col = "SE",
                      freq_col = "AF",
                      A1_col = "ALT",
                      A2_col = "REF",
                      p_col = "PVALUE",
                      n_col = "N")

write.table(Smoking , "./GWAS_26and5_formatted/Smoking", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Smoking_raw","Smoking"))
# Out:
# Rows: 13933175 Columns: 13
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (3): RSID, REF, ALT
# dbl (10): CHROM, POS, AF, STAT, PVALUE, BETA, SE, N, EFFECTIVE_N, Number_of_...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 13933175 dat lines
#
# Remove ambiguous SNPs ..., remaining 11851365 SNPs.
#
# Remove SNPs in MHC region ..., remaining 11797036 SNPs.
#
# Remove duplicated SNPs ..., remaining 11771174 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1200280 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1083540 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1083540 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1078870 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1078870 SNPs.
#
# The formatted data has 1078870 dat lines.

# %%
## 28. SWB

SWB_raw <- readr::read_delim("./GWAS_26and5_raw/SWB", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

SWB = MRAPSS::format_data(SWB_raw,
                          snp_col = "MarkerName",
                          freq_col = "EAF",
                          A1_col = "A1",
                          A2_col = "A2",
                          b_col = "Beta",
                          se_col = "SE",
                          p_col = "Pval",
                          n = 298420)

write.table(SWB, file = "./GWAS_26and5_formatted/SWB", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("SWB_raw","SWB"))
# Out:
# Rows: 2268674 Columns: 9
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): MarkerName, A1, A2
# dbl (6): CHR, POS, EAF, Beta, SE, Pval
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 2268674 dat lines
#
# Remove ambiguous SNPs ..., remaining 1918560 SNPs.
#
# Remove SNPs in MHC region ..., remaining 1915787 SNPs.
#
# Remove duplicated SNPs ..., remaining 1915787 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1018811 SNPs.
#
# Generating sample size from specified sample size
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 975109 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 975109 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 975109 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 975109 SNPs.
#
# The formatted data has 975109 dat lines.

# %%
## 29. T2D

T2D_raw <- readr::read_delim("./GWAS_26and5_raw/T2D_rsid", "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

T2D = MRAPSS::format_data(T2D_raw,
                          snp_col = "rsid",
                          b_col = "Beta",
                          se_col = "SE",
                          freq_col = "EAF",
                          A1_col = "EA",
                          A2_col = "NEA",
                          p_col = "Pvalue",
                          n_col = "Neff")

write.table(T2D, "./GWAS_26and5_formatted/T2D", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("T2D_raw","T2D"))
# Out:
# Rows: 9073559 Columns: 11
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (3): rsid, EA, NEA
# dbl  (7): Chr, Pos, EAF, Beta, SE, Pvalue, Neff
# time (1): SNP
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 9073559 dat lines
#
# Remove ambiguous SNPs ..., remaining 7713357 SNPs.
#
# Remove SNPs in MHC region ..., remaining 7671570 SNPs.
#
# Remove duplicated SNPs ..., remaining 7663228 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1186472 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1058930 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1058930 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1048396 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1048310 SNPs.
#
# The formatted data has 1048310 dat lines.

# %%
## 30. Tanning

dat_raw <- readr::read_delim("./GWAS_26and5_raw/Tanning", delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)

dat = MRAPSS::format_data(dat_raw,
                          snp_col = "SNPID_UKB",
                          b_col = "BETA",
                          se_col = "SE",
                          freq_col = "MAF_UKB",
                          A1_col = "A1",
                          A2_col = "A2",
                          p_col = "P",
                          n_col = "NMISS",
                          info_col = "INFO_UKB")

write.table(dat, "./GWAS_26and5_formatted/Tanning", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("dat_raw", "dat"))
# Out:
# Rows: 10579925 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, BETA, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UK...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 10579925 dat lines
#
# Remove SNPs with imputation info less than 0.9 ..., remaining 10579890 SNPs.
#
# Remove ambiguous SNPs ..., remaining 8978911 SNPs.
#
# Remove SNPs in MHC region ..., remaining 8927942 SNPs.
#
# Remove duplicated SNPs ..., remaining 8927942 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1161467 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1161162 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1037824 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1037824 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1037824 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1037026 SNPs.
#
# The formatted data has 1037026 dat lines.

# %%
## 31. Urate

Urate_raw <- readr::read_delim("./GWAS_26and5_raw/Urate", ",", escape_double = FALSE, trim_ws = TRUE, progress = F)

Urate = format_data(Urate_raw,
                    snp_col = "MarkerName",
                    b_col = "beta",
                    se_col = "se",
                    A1_col = "A1",
                    A2_col = "A2",
                    p_col = "p_gc",
                    n_col = "n_total")

write.table(Urate, "./GWAS_26and5_formatted/Urate", sep = "\t", quote = F, row.names = F, col.names = T)

rm(list=c("Urate_raw","Urate"))
# Out:
# Rows: 2450547 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): MarkerName, A1, A2
# dbl (4): n_total, beta, se, p_gc
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting ....
#
# The raw data set has 2450547 dat lines
#
# Remove ambiguous SNPs ..., remaining 2072342 SNPs.
#
# Remove SNPs in MHC region ..., remaining 2062309 SNPs.
#
# Remove duplicated SNPs ..., remaining 2062309 SNPs.
#
# Merge SNPs with the hapmap3 snplist ..., remaining 1064399 SNPs.
#
# Remove SNPs with alleles not matched with the hapmap3 snplist, remaining 1064363 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1, remaining 1064363 SNPs.
#
# Inferring z score from p value and b ...
#
# Remove missing values, remaining 1064363 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean, remaining 1060694 SNPs.
#
# Remove SNPs with chi2 > chi2_max ... , remaining 1060305 SNPs.
#
# The formatted data has 1060305 dat lines.
