# %%
library(MRAPSS)
library(readr)

# %%
## Estimating parameters for the background model using genome-wide summary statistics;
## using plink clumping to obtain independent IVs

ts1 = c("AD", "ASD", "Daytime_Sleepiness", "Height_UKB",  "Intelligence", "RA",      
        "T2D", "Alcohol", "BMI", "Depression", "IBD", "MDD", "SCZ", "Angina", 
        "CAD", "HBP", "Income", "NEB", "Smoking", "Urate", "Anorexia", 
        "CD", "Height_GIANT", "Insomnia", "Neuroticism", "SWB")

ts2 = c("Hair_Light_Brown", "Hair_Dark_Brown",  "Hair_Black",  "Hair_Blonde",  "Tanning")


for( exposure in ts1){
  for( outcome in ts2){
    
    
    # Start the clock!
    start = proc.time()
    
    # read in formatted GWAS data
    trait1.dir = paste0("./GWAS_26and5_formatted/", exposure)
    trait2.dir = paste0("./GWAS_26and5_formatted/", outcome)
    
    
    cat(exposure,"~",outcome,"\n")
    
    trait1 = readr::read_delim(trait1.dir, delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
    
    trait2 = readr::read_delim(trait2.dir, delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
    
    # estimate parameters for the background model
    paras = est_paras(dat1 = trait1,
                      dat2 = trait2,
                      trait1.name = exposure,
                      trait2.name = outcome,
                      h2.fix.intercept = F,
                      LDSC = T,
                      ldscore.dir = "/import/home/share/xhu/database/1KG/eur_w_ld_chr")
    
    write.table(data.frame(exposure,
                           outcome,
                           nrow(paras$dat),
                           rg = paras$ldsc_res$rg,
                           rg.se = paras$ldsc_res$rg.se,
                           paras$ldsc_res$I[1,1],
                           paras$ldsc_res$I[2,2],
                           rho = paras$ldsc_res$I[1,2],
                           paras$ldsc_res$I.se[1,1],
                           paras$ldsc_res$I.se[2,2],
                           rho = paras$ldsc_res$I.se[1,2],
                           paras$ldsc_res$cov[1,1],  paras$ldsc_res$cov[1,2],  paras$ldsc_res$cov[2,2],
                           paras$ldsc_res$cov.se[1,1],  paras$ldsc_res$cov.se[1,2],  paras$ldsc_res$cov.se[2,2]),
                file = "pairs_ldsc_res", col.names = F, row.names = F, quote=F,append = T)
    
    if(inherits(paras, 'try-error')) next
    
    write.table(matrix(as.vector(paras$Omega), nrow=1), paste0("./pairs_bg_paras/", exposure, "~", outcome, "_Omega"),
                row.names = F, col.names = F, quote = F)
      
    write.table(matrix(as.vector(paras$C), nrow=1), paste0("./pairs_bg_paras/", exposure, "~", outcome, "_C"),
                row.names = F, col.names = F, quote = F)
    
    # clumping      
    cat("Begin clumping ...\n ")
    
    clumped =  clump(paras$dat,
                     IV.Threshold = 5e-05,
                     SNP_col = "SNP",
                     pval_col = "pval.exp",
                     clump_kb = 1000,
                     clump_r2 = 0.001,
                     plink = "/import/home/maxhu/plink/plink",
                     bfile = "/import/home/share/xhu/database/1KG/all_1000G_EUR_Phase3")
    
    if(inherits(clumped , 'try-error')) next
    
    
    write.table(clumped, file = paste0("./MRdat/", exposure,"~",outcome), col.names=T, row.names=F, quote=F)
    
    # Stop the clock
    proc.time() - start
    
  }
  
}
# Out:
# AD ~ Hair_Light_Brown
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1133.
#
# Intercept: 1.0379(0.0099).
#
# Total Observed scale h2:0.0664(0.0131).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6086.
#
# Intercept: 1.3001 (0.014).
#
# Total Observed scale h2:0.0383 (0.006).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0131 (0.0069).
#
# Total Observed scale gencov: 5e-04 (0.0036).
# Begin clumping ...
# API: public: http://gwas-api.mrcieu.ac.uk/
#
# Clumping FkbBDg, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Hair_Dark_Brown
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1133.
#
# Intercept: 1.0384(0.0099).
#
# Total Observed scale h2:0.066(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1931.
#
# Intercept: 1.4611 (0.0186).
#
# Total Observed scale h2:0.0887 (0.0118).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0098 (0.007).
#
# Total Observed scale gencov: -5e-04 (0.0039).
# Begin clumping ...
# Clumping A9OXkz, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Hair_Black
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0382(0.0101).
#
# Total Observed scale h2:0.0662(0.0132).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.096.
#
# Intercept: 1.6301 (0.0175).
#
# Total Observed scale h2:0.0578 (0.0077).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0188 (0.0079).
#
# Total Observed scale gencov: 0.0039 (0.0041).
# Begin clumping ...
# Clumping scufZx, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Hair_Blonde
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1133.
#
# Intercept: 1.0381(0.01).
#
# Total Observed scale h2:0.0663(0.0132).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.8986.
#
# Intercept: 1.2005 (0.0175).
#
# Total Observed scale h2:0.0884 (0.0105).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0095 (0.0065).
#
# Total Observed scale gencov: 0.001 (0.0035).
# Begin clumping ...
# Clumping VfwiGk, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Tanning
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1133.
#
# Intercept: 1.0382(0.01).
#
# Total Observed scale h2:0.0663(0.0135).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6625.
#
# Intercept: 1.8085 (0.0227).
#
# Total Observed scale h2:0.1072 (0.0142).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0067 (0.0082).
#
# Total Observed scale gencov: 0.0069 (0.0041).
# Begin clumping ...
# Clumping CjmB18, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Hair_Light_Brown
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0779.
#
# Intercept: 0.9717(0.0076).
#
# Total Observed scale h2:0.3197(0.0386).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6118.
#
# Intercept: 1.3009 (0.0145).
#
# Total Observed scale h2:0.0386 (0.006).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0021 (0.0063).
#
# Total Observed scale gencov: -0.0063 (0.006).
# Begin clumping ...
# Clumping yCOmQD, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Hair_Dark_Brown
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.078.
#
# Intercept: 0.9716(0.0077).
#
# Total Observed scale h2:0.3203(0.0384).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1972.
#
# Intercept: 1.4639 (0.019).
#
# Total Observed scale h2:0.0889 (0.0119).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0066 (0.0074).
#
# Total Observed scale gencov: 0.0172 (0.007).
# Begin clumping ...
# Clumping uFSt7V, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Hair_Black
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0779.
#
# Intercept: 0.9717(0.0076).
#
# Total Observed scale h2:0.3199(0.0385).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1008.
#
# Intercept: 1.6338 (0.0169).
#
# Total Observed scale h2:0.058 (0.008).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.018 (0.007).
#
# Total Observed scale gencov: -0.0167 (0.0064).
# Begin clumping ...
# Clumping qpSfw4, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Hair_Blonde
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0779.
#
# Intercept: 0.972(0.0074).
#
# Total Observed scale h2:0.3186(0.0378).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9031.
#
# Intercept: 1.2016 (0.0175).
#
# Total Observed scale h2:0.0888 (0.0109).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0028 (0.0056).
#
# Total Observed scale gencov: -0.001 (0.0058).
# Begin clumping ...
# Clumping VUXlKO, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Tanning
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.078.
#
# Intercept: 0.9708(0.0074).
#
# Total Observed scale h2:0.3234(0.0377).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6698.
#
# Intercept: 1.8138 (0.0231).
#
# Total Observed scale h2:0.1073 (0.0147).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0088 (0.0089).
#
# Total Observed scale gencov: -0.0216 (0.008).
# Begin clumping ...
# Clumping 6jFknW, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# Daytime_Sleepiness ~ Hair_Light_Brown
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4833.
#
# Intercept: 1.0327(0.0104).
#
# Total Observed scale h2:0.048(0.0025).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6091.
#
# Intercept: 1.2955 (0.014).
#
# Total Observed scale h2:0.039 (0.006).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0029 (0.0074).
#
# Total Observed scale gencov: 8e-04 (0.0015).
# Begin clumping ...
# Clumping YUh2gR, 2803 variants, using EUR population reference
#
# Removing 2560 of 2803 variants due to LD with other variants or absence from LD reference panel
# Daytime_Sleepiness ~ Hair_Dark_Brown
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4829.
#
# Intercept: 1.0331(0.0106).
#
# Total Observed scale h2:0.0479(0.0025).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.193.
#
# Intercept: 1.453 (0.0195).
#
# Total Observed scale h2:0.0899 (0.0118).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0051 (0.0083).
#
# Total Observed scale gencov: -8e-04 (0.0018).
# Begin clumping ...
# Clumping 7iNN7d, 2797 variants, using EUR population reference
#
# Removing 2555 of 2797 variants due to LD with other variants or absence from LD reference panel
# Daytime_Sleepiness ~ Hair_Black
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4832.
#
# Intercept: 1.0325(0.0105).
#
# Total Observed scale h2:0.048(0.0025).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0972.
#
# Intercept: 1.6247 (0.0177).
#
# Total Observed scale h2:0.0587 (0.0078).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0131 (0.0079).
#
# Total Observed scale gencov: -0.0014 (0.0014).
# Begin clumping ...
# Clumping PzfCWj, 2803 variants, using EUR population reference
#
# Removing 2560 of 2803 variants due to LD with other variants or absence from LD reference panel
# Daytime_Sleepiness ~ Hair_Blonde
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4833.
#
# Intercept: 1.0332(0.0104).
#
# Total Observed scale h2:0.0479(0.0025).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9006.
#
# Intercept: 1.1988 (0.0176).
#
# Total Observed scale h2:0.0889 (0.0107).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0029 (0.0071).
#
# Total Observed scale gencov: 0.0011 (0.0015).
# Begin clumping ...
# Clumping H86xm1, 2803 variants, using EUR population reference
#
# Removing 2560 of 2803 variants due to LD with other variants or absence from LD reference panel
# Daytime_Sleepiness ~ Tanning
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4828.
#
# Intercept: 1.0324(0.0104).
#
# Total Observed scale h2:0.048(0.0025).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.66.
#
# Intercept: 1.7987 (0.0225).
#
# Total Observed scale h2:0.1083 (0.0149).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0143 (0.0078).
#
# Total Observed scale gencov: -0.0012 (0.0018).
# Begin clumping ...
# Clumping 1wJJIh, 2797 variants, using EUR population reference
#
# Removing 2555 of 2797 variants due to LD with other variants or absence from LD reference panel
# Height_UKB ~ Hair_Light_Brown
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.4776.
#
# Intercept: 1.9701(0.0401).
#
# Total Observed scale h2:0.4183(0.0176).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6052.
#
# Intercept: 1.3049 (0.0145).
#
# Total Observed scale h2:0.0374 (0.0059).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.3299 (0.0114).
#
# Total Observed scale gencov: 0.0054 (0.0031).
# Begin clumping ...
# Clumping niY72C, 71718 variants, using EUR population reference
#
# Removing 69492 of 71718 variants due to LD with other variants or absence from LD reference panel
# Height_UKB ~ Hair_Dark_Brown
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.4702.
#
# Intercept: 1.9698(0.0391).
#
# Total Observed scale h2:0.4179(0.0176).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1795.
#
# Intercept: 1.4644 (0.0189).
#
# Total Observed scale h2:0.0873 (0.0118).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.3539 (0.0126).
#
# Total Observed scale gencov: 0.0028 (0.0041).
# Begin clumping ...
# Clumping H5MmvX, 71569 variants, using EUR population reference
#
# Removing 69345 of 71569 variants due to LD with other variants or absence from LD reference panel
# Height_UKB ~ Hair_Black
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.4774.
#
# Intercept: 1.9705(0.0397).
#
# Total Observed scale h2:0.4182(0.0175).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0932.
#
# Intercept: 1.6378 (0.0172).
#
# Total Observed scale h2:0.0566 (0.0078).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.4838 (0.0124).
#
# Total Observed scale gencov: -0.0199 (0.0037).
# Begin clumping ...
# Clumping Vlb9d2, 71715 variants, using EUR population reference
#
# Removing 69488 of 71715 variants due to LD with other variants or absence from LD reference panel
# Height_UKB ~ Hair_Blonde
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.476.
#
# Intercept: 1.9701(0.0391).
#
# Total Observed scale h2:0.4181(0.0175).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.8894.
#
# Intercept: 1.2032 (0.0181).
#
# Total Observed scale h2:0.0873 (0.0108).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.2127 (0.0106).
#
# Total Observed scale gencov: 0.0026 (0.0035).
# Begin clumping ...
# Clumping 1G1ZQ3, 71652 variants, using EUR population reference
#
# Removing 69427 of 71652 variants due to LD with other variants or absence from LD reference panel
# Height_UKB ~ Tanning
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.4392.
#
# Intercept: 1.9717(0.0392).
#
# Total Observed scale h2:0.4167(0.0177).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6434.
#
# Intercept: 1.8121 (0.0224).
#
# Total Observed scale h2:0.1061 (0.0148).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.3609 (0.0139).
#
# Total Observed scale gencov: -0.0067 (0.0046).
# Begin clumping ...
# Clumping PEeFVQ, 71366 variants, using EUR population reference
#
# Removing 69139 of 71366 variants due to LD with other variants or absence from LD reference panel
# Intelligence ~ Hair_Light_Brown
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6916.
#
# Intercept: 1.1088(0.0128).
#
# Total Observed scale h2:0.2192(0.011).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.609.
#
# Intercept: 1.2991 (0.0142).
#
# Total Observed scale h2:0.0386 (0.006).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.074 (0.0077).
#
# Total Observed scale gencov: -0.0062 (0.0031).
# Begin clumping ...
# Clumping a8izSx, 4746 variants, using EUR population reference
#
# Removing 4344 of 4746 variants due to LD with other variants or absence from LD reference panel
# Intelligence ~ Hair_Dark_Brown
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6914.
#
# Intercept: 1.1094(0.0125).
#
# Total Observed scale h2:0.2188(0.0107).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1917.
#
# Intercept: 1.4599 (0.0191).
#
# Total Observed scale h2:0.089 (0.0118).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0265 (0.0077).
#
# Total Observed scale gencov: 0.015 (0.0038).
# Begin clumping ...
# Clumping S3vCcK, 4745 variants, using EUR population reference
#
# Removing 4344 of 4745 variants due to LD with other variants or absence from LD reference panel
# Intelligence ~ Hair_Black
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6916.
#
# Intercept: 1.1092(0.0127).
#
# Total Observed scale h2:0.2189(0.011).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0975.
#
# Intercept: 1.6309 (0.0175).
#
# Total Observed scale h2:0.0581 (0.0078).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.1374 (0.0089).
#
# Total Observed scale gencov: -0.0147 (0.0034).
# Begin clumping ...
# Clumping YnFRKY, 4746 variants, using EUR population reference
#
# Removing 4344 of 4746 variants due to LD with other variants or absence from LD reference panel
# Intelligence ~ Hair_Blonde
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6917.
#
# Intercept: 1.1089(0.0128).
#
# Total Observed scale h2:0.2191(0.011).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.8984.
#
# Intercept: 1.1989 (0.0174).
#
# Total Observed scale h2:0.089 (0.0105).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.017 (0.0077).
#
# Total Observed scale gencov: -0.0035 (0.0035).
# Begin clumping ...
# Clumping GVCfaF, 4746 variants, using EUR population reference
#
# Removing 4344 of 4746 variants due to LD with other variants or absence from LD reference panel
# Intelligence ~ Tanning
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6913.
#
# Intercept: 1.1094(0.0126).
#
# Total Observed scale h2:0.2188(0.0108).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6612.
#
# Intercept: 1.8083 (0.0226).
#
# Total Observed scale h2:0.1075 (0.0149).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.1004 (0.0094).
#
# Total Observed scale gencov: -0.027 (0.0039).
# Begin clumping ...
# Clumping ocPdJ0, 4745 variants, using EUR population reference
#
# Removing 4344 of 4745 variants due to LD with other variants or absence from LD reference panel
# RA ~ Hair_Light_Brown
# Rows: 1029912 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1118.
#
# Intercept: 0.9564(0.0097).
#
# Total Observed scale h2:0.1286(0.0138).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6092.
#
# Intercept: 1.2975 (0.0144).
#
# Total Observed scale h2:0.0387 (0.0059).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0057 (0.006).
#
# Total Observed scale gencov: 0.0108 (0.0033).
# Begin clumping ...
# Clumping hcmxl3, 1449 variants, using EUR population reference
#
# Removing 1314 of 1449 variants due to LD with other variants or absence from LD reference panel
# RA ~ Hair_Dark_Brown
# Rows: 1029912 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1117.
#
# Intercept: 0.9568(0.0097).
#
# Total Observed scale h2:0.1282(0.0139).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1924.
#
# Intercept: 1.4592 (0.0189).
#
# Total Observed scale h2:0.0889 (0.0119).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0045 (0.0075).
#
# Total Observed scale gencov: -0.0102 (0.0039).
# Begin clumping ...
# Clumping 3yB2SL, 1447 variants, using EUR population reference
#
# Removing 1312 of 1447 variants due to LD with other variants or absence from LD reference panel
# RA ~ Hair_Black
# Rows: 1029912 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1117.
#
# Intercept: 0.9566(0.0098).
#
# Total Observed scale h2:0.1283(0.014).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0974.
#
# Intercept: 1.6295 (0.0176).
#
# Total Observed scale h2:0.0581 (0.0078).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 6e-04 (0.0071).
#
# ...
#
# Total Observed scale h2:0.1086(0.0045).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.609.
#
# Intercept: 1.2988 (0.014).
#
# Total Observed scale h2:0.0387 (0.0059).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0283 (0.0079).
#
# Total Observed scale gencov: -0.0013 (0.002).
# Begin clumping ...
# Clumping waQLKH, 6226 variants, using EUR population reference
#
# Removing 5764 of 6226 variants due to LD with other variants or absence from LD reference panel
# Neuroticism ~ Hair_Dark_Brown
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.7534.
#
# Intercept: 1.0462(0.0124).
#
# Total Observed scale h2:0.1085(0.0046).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1917.
#
# Intercept: 1.4592 (0.0192).
#
# Total Observed scale h2:0.0892 (0.0118).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0382 (0.0081).
#
# Total Observed scale gencov: -0.0015 (0.0022).
# Begin clumping ...
# Clumping niUKFl, 6190 variants, using EUR population reference
#
# Removing 5728 of 6190 variants due to LD with other variants or absence from LD reference panel
# Neuroticism ~ Hair_Black
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.7542.
#
# Intercept: 1.0464(0.013).
#
# Total Observed scale h2:0.1085(0.0045).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0975.
#
# Intercept: 1.631 (0.0177).
#
# Total Observed scale h2:0.0581 (0.0078).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0489 (0.0093).
#
# Total Observed scale gencov: 0.0024 (0.0024).
# Begin clumping ...
# Clumping 3UayXr, 6226 variants, using EUR population reference
#
# Removing 5764 of 6226 variants due to LD with other variants or absence from LD reference panel
# Neuroticism ~ Hair_Blonde
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.7543.
#
# Intercept: 1.0462(0.0128).
#
# Total Observed scale h2:0.1086(0.0044).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.8984.
#
# Intercept: 1.1995 (0.0174).
#
# Total Observed scale h2:0.0889 (0.0106).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0247 (0.0073).
#
# Total Observed scale gencov: 0.0013 (0.002).
# Begin clumping ...
# Clumping mQ3QpO, 6226 variants, using EUR population reference
#
# Removing 5764 of 6226 variants due to LD with other variants or absence from LD reference panel
# Neuroticism ~ Tanning
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.7524.
#
# Intercept: 1.0466(0.0127).
#
# Total Observed scale h2:0.1084(0.0045).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6612.
#
# Intercept: 1.8085 (0.0224).
#
# Total Observed scale h2:0.1074 (0.0149).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0044 (0.01).
#
# Total Observed scale gencov: 0.004 (0.0028).
# Begin clumping ...
# Clumping 98rE6W, 6179 variants, using EUR population reference
#
# Removing 5718 of 6179 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Hair_Light_Brown
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037742 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1593.
#
# Intercept: 0.9958(0.008).
#
# Total Observed scale h2:0.026(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6046.
#
# Intercept: 1.2991 (0.0147).
#
# Total Observed scale h2:0.0381 (0.0059).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0027 (0.0071).
#
# Total Observed scale gencov: 0 (0.0015).
# Begin clumping ...
# Clumping 1NoeH2, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Hair_Dark_Brown
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037381 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1591.
#
# Intercept: 0.9963(0.0081).
#
# Total Observed scale h2:0.0259(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.1765.
#
# Intercept: 1.4643 (0.0199).
#
# Total Observed scale h2:0.0865 (0.0112).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0185 (0.008).
#
# Total Observed scale gencov: 4e-04 (0.0017).
# Begin clumping ...
# Clumping wb5ug8, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Hair_Black
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037702 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1593.
#
# Intercept: 0.9962(0.0078).
#
# Total Observed scale h2:0.0259(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0874.
#
# Intercept: 1.6279 (0.0176).
#
# Total Observed scale h2:0.0574 (0.008).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0 (0.0078).
#
# Total Observed scale gencov: 0.0018 (0.0016).
# Begin clumping ...
# Clumping Sck1wS, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Hair_Blonde
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037533 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1594.
#
# Intercept: 0.9961(0.0078).
#
# Total Observed scale h2:0.026(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.8881.
#
# Intercept: 1.204 (0.0181).
#
# Total Observed scale h2:0.0871 (0.0108).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0103 (0.0063).
#
# Total Observed scale gencov: -0.0013 (0.0015).
# Begin clumping ...
# Clumping qX8oJw, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Tanning
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037026 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1584.
#
# Intercept: 0.9964(0.0079).
#
# Total Observed scale h2:0.0258(0.0023).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.6479.
#
# Intercept: 1.8084 (0.0219).
#
# Total Observed scale h2:0.1058 (0.0142).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0085 (0.0086).
#
# Total Observed scale gencov: -1e-04 (0.002).
# Begin clumping ...
# Clumping 3P4nZw, 285 variants, using EUR population reference
#
# Removing 221 of 285 variants due to LD with other variants or absence from LD reference panel
