# %%
library(MRAPSS)
library(readr)

# %%
## Estimating parameters for the background model using genome-wide summary statistics;
## using plink clumping to obtain independent IVs

ts1 = c("AD", "ASD", "Daytime_Sleepiness", "Height_UKB",  "Intelligence", "RA",      
        "T2D", "Alcohol", "BMI", "Depression", "IBD", "MDD", "SCZ", "Angina", 
        "CAD", "HBP", "Income", "NEB", "Smoking", "Urate", "Anorexia", 
        "CD", "Height_GIANT", "Insomnia", "Neuroticism", "SWB")

ts2 = ts1


for( exposure in ts1){
  for( outcome in ts2){
    
    if(exposure==outcome) next
      
    # Start the clock!
    start = proc.time()
    
    # read in formatted GWAS data
    trait1.dir = paste0("./GWAS_26and5_formatted/", exposure)
    trait2.dir = paste0("./GWAS_26and5_formatted/", outcome)
    
    
    cat(exposure,"~",outcome,"\n")
    
    trait1 = readr::read_delim(trait1.dir, delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
    
    trait2 = readr::read_delim(trait2.dir, delim = "\t", escape_double = FALSE, trim_ws = TRUE, progress = F)
    
    # estimate parameters for the background model
    paras = est_paras(dat1 = trait1,
                      dat2 = trait2,
                      trait1.name = exposure,
                      trait2.name = outcome,
                      h2.fix.intercept = F,
                      LDSC = T,
                      ldscore.dir = "/import/home/share/xhu/database/1KG/eur_w_ld_chr")
    
    write.table(data.frame(exposure,
                           outcome,
                           nrow(paras$dat),
                           rg = paras$ldsc_res$rg,
                           rg.se = paras$ldsc_res$rg.se,
                           paras$ldsc_res$I[1,1],
                           paras$ldsc_res$I[2,2],
                           rho = paras$ldsc_res$I[1,2],
                           paras$ldsc_res$I.se[1,1],
                           paras$ldsc_res$I.se[2,2],
                           rho = paras$ldsc_res$I.se[1,2],
                           paras$ldsc_res$cov[1,1],  paras$ldsc_res$cov[1,2],  paras$ldsc_res$cov[2,2],
                           paras$ldsc_res$cov.se[1,1],  paras$ldsc_res$cov.se[1,2],  paras$ldsc_res$cov.se[2,2]),
                file = "pairs_ldsc_res", col.names = F, row.names = F, quote=F,append = T)
    
    if(inherits(paras, 'try-error')) next
    
    write.table(matrix(as.vector(paras$Omega), nrow=1), paste0("./pairs_bg_paras/", exposure, "~", outcome, "_Omega"),
                row.names = F, col.names = F, quote = F)
      
    write.table(matrix(as.vector(paras$C), nrow=1), paste0("./pairs_bg_paras/", exposure, "~", outcome, "_C"),
                row.names = F, col.names = F, quote = F)
    
    # clumping      
    cat("Begin clumping ...\n ")
    
    clumped =  clump(paras$dat,
                     IV.Threshold = 5e-05,
                     SNP_col = "SNP",
                     pval_col = "pval.exp",
                     clump_kb = 1000,
                     clump_r2 = 0.001,
                     plink = "/import/home/maxhu/plink/plink",
                     bfile = "/import/home/share/xhu/database/1KG/all_1000G_EUR_Phase3")
    
    if(inherits(clumped , 'try-error')) next
    
    
    write.table(clumped, file = paste0("./MRdat/", exposure,"~",outcome), col.names=T, row.names=F, quote=F)
    
    # Stop the clock
    proc.time() - start
    
  }
  
}
# Out:
# AD ~ ASD
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.112.
#
# Intercept: 1.034(0.0089).
#
# Total Observed scale h2:0.0704(0.0135).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.075.
#
# Intercept: 0.9675 (0.007).
#
# Total Observed scale h2:0.3306 (0.0356).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -3e-04 (0.0052).
#
# Total Observed scale gencov: -0.0051 (0.0127).
# Begin clumping ...
# API: public: http://gwas-api.mrcieu.ac.uk/
#
# Clumping t8vIKo, 576 variants, using EUR population reference
#
# Removing 504 of 576 variants due to LD with other variants or absence from LD reference panel
# AD ~ Daytime_Sleepiness
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1122.
#
# Intercept: 1.0358(0.0087).
#
# Total Observed scale h2:0.0684(0.0133).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4774.
#
# Intercept: 1.0326 (0.0113).
#
# Total Observed scale h2:0.048 (0.0027).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0011 (0.0061).
#
# Total Observed scale gencov: 3e-04 (0.003).
# Begin clumping ...
# Clumping eKGDhC, 567 variants, using EUR population reference
#
# Removing 497 of 567 variants due to LD with other variants or absence from LD reference panel
# AD ~ Height_UKB
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0414(0.0102).
#
# Total Observed scale h2:0.0631(0.0136).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.4837.
#
# Intercept: 1.9783 (0.0417).
#
# Total Observed scale h2:0.4161 (0.0176).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0178 (0.0103).
#
# Total Observed scale gencov: -0.0208 (0.0065).
# Begin clumping ...
# Clumping eORqBN, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Intelligence
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0373(0.0101).
#
# Total Observed scale h2:0.067(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6942.
#
# Intercept: 1.1117 (0.0133).
#
# Total Observed scale h2:0.2181 (0.011).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0023 (0.0071).
#
# Total Observed scale gencov: -0.0402 (0.0069).
# Begin clumping ...
# Clumping ZfPK6C, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ RA
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1029912 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1136.
#
# Intercept: 1.0386(0.0102).
#
# Total Observed scale h2:0.0661(0.0136).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1118.
#
# Intercept: 0.9567 (0.0101).
#
# Total Observed scale h2:0.1282 (0.0136).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0155 (0.0055).
#
# Total Observed scale gencov: -0.008 (0.0075).
# Begin clumping ...
# Clumping ldvQQO, 555 variants, using EUR population reference
#
# Removing 486 of 555 variants due to LD with other variants or absence from LD reference panel
# AD ~ T2D
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1048310 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.112.
#
# Intercept: 1.0336(0.0084).
#
# Total Observed scale h2:0.0705(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9918.
#
# Intercept: 1.1029 (0.0183).
#
# Total Observed scale h2:0.1869 (0.0076).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0065 (0.0079).
#
# Total Observed scale gencov: 0.0086 (0.0057).
# Begin clumping ...
# Clumping ZwNJpz, 559 variants, using EUR population reference
#
# Removing 488 of 559 variants due to LD with other variants or absence from LD reference panel
# AD ~ Alcohol
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1084534 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1112.
#
# Intercept: 1.0361(0.0084).
#
# Total Observed scale h2:0.0678(0.0126).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6139.
#
# Intercept: 1.0239 (0.0108).
#
# Total Observed scale h2:0.0686 (0.0032).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0 (0.0062).
#
# Total Observed scale gencov: -4e-04 (0.0035).
# Begin clumping ...
# Clumping 5hiDzk, 575 variants, using EUR population reference
#
# Removing 501 of 575 variants due to LD with other variants or absence from LD reference panel
# AD ~ BMI
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037799 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0401(0.0099).
#
# Total Observed scale h2:0.0644(0.0132).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.9466.
#
# Intercept: 1.1791 (0.02).
#
# Total Observed scale h2:0.2169 (0.0068).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0017 (0.0081).
#
# Total Observed scale gencov: 0.0057 (0.0051).
# Begin clumping ...
# Clumping Jlj6Xb, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Depression
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1026744 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1135.
#
# Intercept: 1.0369(0.0101).
#
# Total Observed scale h2:0.0674(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.3836.
#
# Intercept: 1.0118 (0.0102).
#
# Total Observed scale h2:0.0475 (0.0028).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0028 (0.0066).
#
# Total Observed scale gencov: 0.0067 (0.0035).
# Begin clumping ...
# Clumping M0QPDv, 555 variants, using EUR population reference
#
# Removing 487 of 555 variants due to LD with other variants or absence from LD reference panel
# AD ~ IBD
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1004597 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1125.
#
# Intercept: 1.036(0.0097).
#
# Total Observed scale h2:0.0675(0.0135).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4921.
#
# Intercept: 1.1528 (0.013).
#
# Total Observed scale h2:0.2655 (0.0229).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0106 (0.0061).
#
# Total Observed scale gencov: 0.0039 (0.0076).
# Begin clumping ...
# Clumping fruU0N, 535 variants, using EUR population reference
#
# Removing 466 of 535 variants due to LD with other variants or absence from LD reference panel
# AD ~ MDD
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0374(0.01).
#
# Total Observed scale h2:0.0669(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0672.
#
# Intercept: 0.9862 (0.0077).
#
# Total Observed scale h2:0.0165 (0.0025).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.005 (0.0056).
#
# Total Observed scale gencov: -9e-04 (0.0033).
# Begin clumping ...
# Clumping tYlHPG, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ SCZ
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1047564 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1121.
#
# Intercept: 1.0346(0.0099).
#
# Total Observed scale h2:0.0695(0.0139).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9914.
#
# Intercept: 1.0926 (0.0141).
#
# Total Observed scale h2:0.4072 (0.0149).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0272 (0.0066).
#
# Total Observed scale gencov: 0.0129 (0.007).
# Begin clumping ...
# Clumping y4rOle, 560 variants, using EUR population reference
#
# Removing 493 of 560 variants due to LD with other variants or absence from LD reference panel
# AD ~ Angina
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.0375(0.01).
#
# Total Observed scale h2:0.0668(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1721.
#
# Intercept: 1.0284 (0.0088).
#
# Total Observed scale h2:0.0242 (0.0027).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0083 (0.0059).
#
# Total Observed scale gencov: -0.0024 (0.0032).
# Begin clumping ...
# Clumping qqJ5RL, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ CAD
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1112977 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1104.
#
# Intercept: 1.0337(0.0082).
#
# Total Observed scale h2:0.0699(0.0124).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1369.
#
# Intercept: 0.892 (0.0088).
#
# Total Observed scale h2:0.0654 (0.0051).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0036 (0.0055).
#
# Total Observed scale gencov: -1e-04 (0.004).
# Begin clumping ...
# Clumping eNLcj8, 584 variants, using EUR population reference
#
# Removing 509 of 584 variants due to LD with other variants or absence from LD reference panel
# AD ~ HBP
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.038(0.0099).
#
# Total Observed scale h2:0.0664(0.0133).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.0476.
#
# Intercept: 1.122 (0.0168).
#
# Total Observed scale h2:0.1141 (0.0047).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0102 (0.0071).
#
# Total Observed scale gencov: -0.0061 (0.0042).
# Begin clumping ...
# Clumping 7MEPpA, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ Income
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1208814 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1084.
#
# Intercept: 1.0417(0.0075).
#
# Total Observed scale h2:0.0621(0.0123).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4515.
#
# Intercept: 1.0342 (0.009).
#
# Total Observed scale h2:0.0744 (0.0035).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -9e-04 (0.0053).
#
# Total Observed scale gencov: -0.0121 (0.0039).
# Begin clumping ...
# Clumping dUIyRD, 595 variants, using EUR population reference
#
# Removing 516 of 595 variants due to LD with other variants or absence from LD reference panel
# AD ~ NEB
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 984184 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1085.
#
# Intercept: 1.0353(0.0073).
#
# Total Observed scale h2:0.0668(0.0122).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.138.
#
# Intercept: 0.9764 (0.0082).
#
# Total Observed scale h2:0.0234 (0.0021).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0111 (0.0054).
#
# Total Observed scale gencov: -0.0019 (0.0033).
# Begin clumping ...
# Clumping ZMOH7D, 474 variants, using EUR population reference
#
# Removing 409 of 474 variants due to LD with other variants or absence from LD reference panel
# AD ~ Smoking
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1043420 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1117.
#
# Intercept: 1.0347(0.0086).
#
# Total Observed scale h2:0.0695(0.0132).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.3229.
#
# Intercept: 0.9763 (0.0098).
#
# Total Observed scale h2:0.0682 (0.004).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0125 (0.0058).
#
# Total Observed scale gencov: 9e-04 (0.0036).
# Begin clumping ...
# Clumping in4GVF, 552 variants, using EUR population reference
#
# Removing 480 of 552 variants due to LD with other variants or absence from LD reference panel
# AD ~ Urate
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1060305 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1056.
#
# Intercept: 1.0403(0.0081).
#
# Total Observed scale h2:0.061(0.0122).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.108.
#
# Intercept: 0.9007 (0.0082).
#
# Total Observed scale h2:0.096 (0.009).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 7e-04 (0.0045).
#
# Total Observed scale gencov: -0.0011 (0.0047).
# Begin clumping ...
# Clumping K8l9cq, 500 variants, using EUR population reference
#
# Removing 425 of 500 variants due to LD with other variants or absence from LD reference panel
# AD ~ Anorexia
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 910374 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1167.
#
# Intercept: 1.0385(0.0118).
#
# Total Observed scale h2:0.0661(0.0142).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.3069.
#
# Intercept: 1.0273 (0.0108).
#
# Total Observed scale h2:0.1784 (0.0131).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.01 (0.0063).
#
# Total Observed scale gencov: -1e-04 (0.0075).
# Begin clumping ...
# Clumping FkNJMX, 523 variants, using EUR population reference
#
# Removing 451 of 523 variants due to LD with other variants or absence from LD reference panel
# AD ~ CD
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1004565 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1125.
#
# Intercept: 1.0362(0.0097).
#
# Total Observed scale h2:0.0674(0.0134).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4322.
#
# Intercept: 1.1207 (0.0124).
#
# Total Observed scale h2:0.3604 (0.0324).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0072 (0.0061).
#
# Total Observed scale gencov: 1e-04 (0.0088).
# Begin clumping ...
# Clumping UP6OGh, 535 variants, using EUR population reference
#
# Removing 466 of 535 variants due to LD with other variants or absence from LD reference panel
# AD ~ Height_GIANT
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 961042 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1103.
#
# Intercept: 1.0364(0.009).
#
# Total Observed scale h2:0.0667(0.0126).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.9989.
#
# Intercept: 1.3444 (0.0224).
#
# Total Observed scale h2:0.3086 (0.0138).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0064 (0.0077).
#
# Total Observed scale gencov: -0.0182 (0.006).
# Begin clumping ...
# Clumping ybSV0V, 472 variants, using EUR population reference
#
# Removing 407 of 472 variants due to LD with other variants or absence from LD reference panel
# AD ~ Insomnia
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1065149 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1122.
#
# Intercept: 1.0358(0.0085).
#
# Total Observed scale h2:0.0683(0.0133).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6068.
#
# Intercept: 1.0345 (0.0109).
#
# Total Observed scale h2:0.0607 (0.0026).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0049 (0.0065).
#
# Total Observed scale gencov: -6e-04 (0.0034).
# Begin clumping ...
# Clumping JEoCbW, 567 variants, using EUR population reference
#
# Removing 497 of 567 variants due to LD with other variants or absence from LD reference panel
# AD ~ Neuroticism
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1132.
#
# Intercept: 1.038(0.01).
#
# Total Observed scale h2:0.0664(0.0133).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.7555.
#
# Intercept: 1.043 (0.0129).
#
# Total Observed scale h2:0.1092 (0.0045).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0149 (0.0073).
#
# Total Observed scale gencov: 0.0104 (0.0044).
# Begin clumping ...
# Clumping wqTDey, 557 variants, using EUR population reference
#
# Removing 488 of 557 variants due to LD with other variants or absence from LD reference panel
# AD ~ SWB
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1077.
#
# Intercept: 1.031(0.0076).
#
# Total Observed scale h2:0.0698(0.0123).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1554.
#
# Intercept: 0.9986 (0.0074).
#
# Total Observed scale h2:0.0254 (0.0023).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0074 (0.006).
#
# Total Observed scale gencov: -0.0043 (0.0034).
# Begin clumping ...
# Clumping jWKPDN, 477 variants, using EUR population reference
#
# Removing 409 of 477 variants due to LD with other variants or absence from LD reference panel
# ASD ~ AD
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1148476 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.075.
#
# Intercept: 0.9675(0.007).
#
# Total Observed scale h2:0.3306(0.0356).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.112.
#
# Intercept: 1.034 (0.0089).
#
# Total Observed scale h2:0.0704 (0.0135).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -3e-04 (0.0052).
#
# Total Observed scale gencov: -0.0051 (0.0127).
# Begin clumping ...
# Clumping hC6t0S, 99 variants, using EUR population reference
#
# Removing 59 of 99 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Daytime_Sleepiness
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1065141 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.077.
#
# Intercept: 0.9718(0.0072).
#
# Total Observed scale h2:0.3212(0.0381).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4791.
#
# Intercept: 1.0322 (0.0111).
#
# Total Observed scale h2:0.0482 (0.0027).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0054 (0.0063).
#
# Total Observed scale gencov: 0.0058 (0.006).
# Begin clumping ...
# Clumping SgE5vE, 100 variants, using EUR population reference
#
# Removing 60 of 100 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Height_UKB
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037320 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0775.
#
# Intercept: 0.9689(0.0077).
#
# Total Observed scale h2:0.3283(0.0377).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:5.5016.
#
# Intercept: 1.982 (0.04).
#
# Total Observed scale h2:0.4182 (0.0178).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0133 (0.0091).
#
# Total Observed scale gencov: -0.0042 (0.0111).
# Begin clumping ...
# Clumping hQmJHn, 97 variants, using EUR population reference
#
# Removing 58 of 97 variants due to LD with other variants or absence from LD reference panel
# ASD ~ Intelligence
# Rows: 1076873 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1574.
#
# Intercept: 0.9963(0.0076).
#
# Total Observed scale h2:0.0261(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9749.
#
# Intercept: 1.1017 (0.0179).
#
# Total Observed scale h2:0.1849 (0.0073).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0073 (0.0068).
#
# Total Observed scale gencov: -0.0027 (0.0025).
# Begin clumping ...
# Clumping fJUQhB, 285 variants, using EUR population reference
#
# Removing 219 of 285 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Alcohol
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1084534 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1558.
#
# Intercept: 0.9958(0.0075).
#
# Total Observed scale h2:0.026(0.0023).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.6084.
#
# Intercept: 1.0214 (0.0111).
#
# Total Observed scale h2:0.0687 (0.0031).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0084 (0.0071).
#
# Total Observed scale gencov: -0.0018 (0.0017).
# Begin clumping ...
# Clumping xzF1VW, 289 variants, using EUR population reference
#
# Removing 223 of 289 variants due to LD with other variants or absence from LD reference panel
# SWB ~ BMI
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037799 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1591.
#
# Intercept: 0.9975(0.008).
#
# Total Observed scale h2:0.0257(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:2.9224.
#
# Intercept: 1.1787 (0.02).
#
# Total Observed scale h2:0.2157 (0.0065).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: 0.0027 (0.0076).
#
# Total Observed scale gencov: -0.0023 (0.002).
# Begin clumping ...
# Clumping ZyQMJN, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Depression
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1026744 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1603.
#
# Intercept: 0.9968(0.0081).
#
# Total Observed scale h2:0.0259(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.3824.
#
# Intercept: 1.0123 (0.0108).
#
# Total Observed scale h2:0.0477 (0.0028).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0476 (0.0069).
#
# Total Observed scale gencov: -0.0269 (0.0018).
# Begin clumping ...
# Clumping X91dL5, 286 variants, using EUR population reference
#
# Removing 222 of 286 variants due to LD with other variants or absence from LD reference panel
# SWB ~ IBD
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1004597 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1594.
#
# Intercept: 0.9964(0.0081).
#
# Total Observed scale h2:0.026(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.4818.
#
# Intercept: 1.1547 (0.0126).
#
# Total Observed scale h2:0.2575 (0.0234).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0013 (0.0067).
#
# Total Observed scale gencov: 0.0032 (0.0039).
# Begin clumping ...
# Clumping fpftbw, 281 variants, using EUR population reference
#
# Removing 216 of 281 variants due to LD with other variants or absence from LD reference panel
# SWB ~ MDD
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1593.
#
# Intercept: 0.996(0.0082).
#
# Total Observed scale h2:0.026(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.0676.
#
# Intercept: 0.9868 (0.008).
#
# Total Observed scale h2:0.0165 (0.0028).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0165 (0.0057).
#
# Total Observed scale gencov: -0.0086 (0.0016).
# Begin clumping ...
# Clumping JkAsPo, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ SCZ
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1047564 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1551.
#
# Intercept: 0.997(0.0079).
#
# Total Observed scale h2:0.0256(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.9778.
#
# Intercept: 1.0943 (0.0143).
#
# Total Observed scale h2:0.4041 (0.0152).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0149 (0.0071).
#
# Total Observed scale gencov: -0.0312 (0.0037).
# Begin clumping ...
# Clumping 83tabL, 284 variants, using EUR population reference
#
# Removing 219 of 284 variants due to LD with other variants or absence from LD reference panel
# SWB ~ Angina
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1593.
#
# Intercept: 0.996(0.0081).
#
# Total Observed scale h2:0.026(0.0024).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1705.
#
# Intercept: 1.0313 (0.0091).
#
# Total Observed scale h2:0.0236 (0.0028).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0038 (0.006).
#
# Total Observed scale gencov: -0.0021 (0.0015).
# Begin clumping ...
# Clumping KFIVhO, 287 variants, using EUR population reference
#
# Removing 222 of 287 variants due to LD with other variants or absence from LD reference panel
# SWB ~ CAD
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1112977 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1554.
#
# Intercept: 0.9964(0.0075).
#
# Total Observed scale h2:0.0258(0.0023).
#
#
# Estimate heritability for trait 2 ...
#
# Using two-step estimator with cutoff at 30.
#
# Mean Chi2:1.1347.
#
# Intercept: 0.8896 (0.0096).
#
# Total Observed scale h2:0.0654 (0.0051).
#
#
# Estimate genetic covariance ...
#
# Using two-step estimator with cutoff at 30.
#
# Intercept: -0.0116 (0.0059).
#
# Total Observed scale gencov: 2e-04 (0.0019).
# Begin clumping ...
# Clumping WRj6xX, 289 variants, using EUR population reference
#
# Removing 223 of 289 variants due to LD with other variants or absence from LD reference panel
# SWB ~ HBP
# Rows: 975109 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Rows: 1037824 Columns: 7
#
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
# dbl (4): Z, N, chi2, P
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Merge dat1 and dat2 by SNP ...
#
# Harmonize the direction of SNP effects of exposure and outcome
#
# Read in LD scores ...
#
# Add LD scores to the harmonized data set...
#
# The Harmonized data set will also be used for MR analysis
#
#
# Begin estimation of C and Omega using LDSC ...
#
# Estimate heritability for trait 1 ...
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
