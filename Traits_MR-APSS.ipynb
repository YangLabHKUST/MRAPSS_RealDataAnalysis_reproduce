# %% [markdown]
# # The function for calling MRAPSS() from MRAPSS package

# %%
run_APSS_func <- function(clumped=NULL,
                          exposure=NULL,
                          outcome=NULL,
                          C = diag(2),
                          Omega = matrix(0, 2, 2),
                          IV.Threshold = 5e-08, # IV selection threshold
                          Threshold = 5e-08,    # threshold for correcting for selection bias
                          Cor.SelectionBias=T){
  
 
  res=NULL
  
  for(i in 1:length(Threshold)){
    
    if(!is.null(clumped)){
      
      test = subset(clumped, pval.exp <= IV.Threshold[i])
      if(nrow(test) < 4 ) next
      test$Threshold = Threshold[i]
      cat("IV selection threshold:", IV.Threshold[i] ,"\n")
      
      
      MRres = try(MRAPSS::MRAPSS(test,
                                 exposure=exposure,
                                 outcome=outcome,
                                 C= C,
                                 Omega= Omega,
                                 Cor.SelectionBias = Cor.SelectionBias))
      
      if(inherits(MRres, 'try-error')) {
        MRres=NULL
      }
    }
    
    
    res0 = data.frame(exposure = MRres$exposure,
                      outcome = MRres$outcome,
                      nSNP = nrow(MRres$MRdat),
                      pi0 = MRres$pi0,
                      nvalid = nrow(MRres$MRdat)*MRres$pi0,
                      sigma.sq= MRres$sigma.sq,
                      tau.sq= MRres$tau.sq,
                      beta = MRres$beta,
                      se = MRres$beta.se,
                      pval= MRres$pvalue,
                      method = MRres$method,
                      Threshold = Threshold[i],
                      IVstrength = MRres$IVsignal.sum
    )
    
    if(nrow(res0)!=0){
      res0$IV.Threshold = IV.Threshold[i]
    }
    
    res = rbind(res, res0)
    
  }
  
  return(res)
  
}

# %% [markdown]
# # Run MR-APSS at IV threshold 5e-05 (default)

# %%
# All the results will be saved to the file "Traits_MRAPSS.MRres"
start = proc.time()

ts1 = c("AD", "ASD", "Daytime_Sleepiness", "Height_UKB",  "Intelligence", "RA",      
        "T2D", "Alcohol", "BMI", "Depression", "IBD", "MDD", "SCZ", "Angina", 
        "CAD", "HBP", "Income", "NEB", "Smoking", "Urate", "Anorexia", 
        "CD", "Height_GIANT", "Insomnia", "Neuroticism", "SWB")

ts2 = ts1

IV.Threshold = 5e-05

for( exposure in ts1){
  
  for( outcome in ts2){
    
    if(exposure==outcome) next
      
    cat("Pair: ", exposure,"~", outcome,"\n")
      
    # read in GWAS summary data for IVs
    clumped = try(read.table(paste0("./MRdat/", exposure,"~",outcome), header = T))
    
    # read in background parameters Omega and C
    C = try(as.matrix(read.table(paste0("./pairs_bg_paras/",exposure, "~", outcome,"_C"),
                                 header = F)))
    
    C = matrix(C[nrow(C), ], 2,2)
    
    Omega = try(as.matrix(read.table(paste0("./pairs_bg_paras/", exposure, "~", outcome,"_Omega"),
                                     header = F)))
      
    Omega = matrix(Omega[nrow(Omega), ], 2, 2)
    
    if(inherits(clumped , 'try-error')) clumped = NULL
    if(inherits(C, 'try-error')) next
    if(inherits(Omega, 'try-error')) next
    if(nrow(clumped) < 4 ) next
    
    # The p-value threshold for selection bias correction
    Threshold =  ifelse(IV.Threshold==5e-05, unique(clumped$Threshold), IV.Threshold)
    
    # MR-APSS
    cat("Run MR-APSS ... \n")
    res = run_APSS_func(clumped = clumped,
                        exposure = exposure,
                        outcome = outcome,
                        C = C,
                        Omega=Omega,
                        IV.Threshold = IV.Threshold,
                        Threshold = Threshold,
                        Cor.SelectionBias = T)
    
     
     # saving resuts
     write.table(res, "Traits_MRAPSS.MRres", quote=F, col.names = F, append = T,row.names = F)
     
     
}
  
}

print(proc.time()-start)
# Out:
# Pair:  AD ~ ASD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  ASD :
# MR-APSS: beta =  0.011 , beta.se =  0.0739 , p-value =  8.8180e-01 .
# Total NO. of IVs=  72 , NO. of valid IVs with foreground signals:  18.70112 .
# ***********************************************************
# Pair:  AD ~ Daytime_Sleepiness
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Daytime_Sleepiness :
# MR-APSS: beta =  0.01 , beta.se =  0.0154 , p-value =  5.1838e-01 .
# Total NO. of IVs=  70 , NO. of valid IVs with foreground signals:  18.81116 .
# ***********************************************************
# Pair:  AD ~ Height_UKB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Height_UKB :
# MR-APSS: beta =  0.0424 , beta.se =  0.0298 , p-value =  1.5543e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  16.97834 .
# ***********************************************************
# Pair:  AD ~ Intelligence
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Intelligence :
# MR-APSS: beta =  0.0186 , beta.se =  0.0488 , p-value =  7.0273e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  19.3063 .
# ***********************************************************
# Pair:  AD ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  RA :
# MR-APSS: beta =  -0.0264 , beta.se =  0.0404 , p-value =  5.1399e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  16.78603 .
# ***********************************************************
# Pair:  AD ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  T2D :
# MR-APSS: beta =  -0.0586 , beta.se =  0.0333 , p-value =  7.8928e-02 .
# Total NO. of IVs=  71 , NO. of valid IVs with foreground signals:  19.50717 .
# ***********************************************************
# Pair:  AD ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Alcohol :
# MR-APSS: beta =  -0.014 , beta.se =  0.0202 , p-value =  4.8908e-01 .
# Total NO. of IVs=  74 , NO. of valid IVs with foreground signals:  18.75627 .
# ***********************************************************
# Pair:  AD ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  BMI :
# MR-APSS: beta =  -0.016 , beta.se =  0.0293 , p-value =  5.8346e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  18.26211 .
# ***********************************************************
# Pair:  AD ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Depression :
# MR-APSS: beta =  -3e-04 , beta.se =  0.0162 , p-value =  9.8694e-01 .
# Total NO. of IVs=  68 , NO. of valid IVs with foreground signals:  17.27834 .
# ***********************************************************
# Pair:  AD ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  IBD :
# MR-APSS: beta =  0.0607 , beta.se =  0.0643 , p-value =  3.4474e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  17.47261 .
# ***********************************************************
# Pair:  AD ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  MDD :
# MR-APSS: beta =  -0.0115 , beta.se =  0.0195 , p-value =  5.5477e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  17.18142 .
# ***********************************************************
# Pair:  AD ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  SCZ :
# MR-APSS: beta =  -0.0802 , beta.se =  0.0422 , p-value =  5.7303e-02 .
# Total NO. of IVs=  67 , NO. of valid IVs with foreground signals:  19.97172 .
# ***********************************************************
# Pair:  AD ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Angina :
# MR-APSS: beta =  -0.0165 , beta.se =  0.0184 , p-value =  3.6917e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  17.16725 .
# ***********************************************************
# Pair:  AD ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  CAD :
# MR-APSS: beta =  -0.0116 , beta.se =  0.023 , p-value =  6.1460e-01 .
# Total NO. of IVs=  75 , NO. of valid IVs with foreground signals:  19.23792 .
# ***********************************************************
# Pair:  AD ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  HBP :
# MR-APSS: beta =  0.0073 , beta.se =  0.0236 , p-value =  7.5662e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  18.49143 .
# ***********************************************************
# Pair:  AD ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Income :
# MR-APSS: beta =  0.0065 , beta.se =  0.0192 , p-value =  7.3589e-01 .
# Total NO. of IVs=  79 , NO. of valid IVs with foreground signals:  19.73371 .
# ***********************************************************
# Pair:  AD ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  NEB :
# MR-APSS: beta =  -0.0226 , beta.se =  0.0199 , p-value =  2.5604e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  17.79819 .
# ***********************************************************
# Pair:  AD ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Smoking :
# MR-APSS: beta =  7e-04 , beta.se =  0.0207 , p-value =  9.7198e-01 .
# Total NO. of IVs=  72 , NO. of valid IVs with foreground signals:  18.57148 .
# ***********************************************************
# Pair:  AD ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Urate :
# MR-APSS: beta =  -0.0575 , beta.se =  0.0283 , p-value =  4.1664e-02 .
# Total NO. of IVs=  75 , NO. of valid IVs with foreground signals:  19.33699 .
# ***********************************************************
# Pair:  AD ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Anorexia :
# MR-APSS: beta =  0.0088 , beta.se =  0.0401 , p-value =  8.2709e-01 .
# Total NO. of IVs=  72 , NO. of valid IVs with foreground signals:  20.14084 .
# ***********************************************************
# Pair:  AD ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  CD :
# MR-APSS: beta =  0.0222 , beta.se =  0.0636 , p-value =  7.2690e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  16.6697 .
# ***********************************************************
# Pair:  AD ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Height_GIANT :
# MR-APSS: beta =  3e-04 , beta.se =  0.026 , p-value =  9.9058e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  17.81756 .
# ***********************************************************
# Pair:  AD ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Insomnia :
# MR-APSS: beta =  -0.0054 , beta.se =  0.0166 , p-value =  7.4466e-01 .
# Total NO. of IVs=  70 , NO. of valid IVs with foreground signals:  18.68998 .
# ***********************************************************
# Pair:  AD ~ Neuroticism
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  Neuroticism :
# MR-APSS: beta =  -0.0155 , beta.se =  0.0229 , p-value =  4.9980e-01 .
# Total NO. of IVs=  69 , NO. of valid IVs with foreground signals:  17.6841 .
# ***********************************************************
# Pair:  AD ~ SWB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  AD  on  SWB :
# MR-APSS: beta =  0.0157 , beta.se =  0.0209 , p-value =  4.5208e-01 .
# Total NO. of IVs=  68 , NO. of valid IVs with foreground signals:  17.75021 .
# ***********************************************************
# Pair:  ASD ~ AD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  AD :
# MR-APSS: beta =  -0.0098 , beta.se =  0.0841 , p-value =  9.0721e-01 .
# Total NO. of IVs=  40 , NO. of valid IVs with foreground signals:  39.99333 .
# ***********************************************************
# Pair:  ASD ~ Daytime_Sleepiness
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Daytime_Sleepiness :
# MR-APSS: beta =  -0.0734 , beta.se =  0.0323 , p-value =  2.2888e-02 .
# Total NO. of IVs=  40 , NO. of valid IVs with foreground signals:  39.98983 .
# ***********************************************************
# Pair:  ASD ~ Height_UKB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Height_UKB :
# MR-APSS: beta =  0.0857 , beta.se =  0.0624 , p-value =  1.7009e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.9945 .
# ***********************************************************
# Pair:  ASD ~ Intelligence
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Intelligence :
# MR-APSS: beta =  0.0162 , beta.se =  0.0813 , p-value =  8.4222e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.9644 .
# ***********************************************************
# Pair:  ASD ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  RA :
# MR-APSS: beta =  0.1033 , beta.se =  0.104 , p-value =  3.2072e-01 .
# Total NO. of IVs=  37 , NO. of valid IVs with foreground signals:  20.87723 .
# ***********************************************************
# Pair:  ASD ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  T2D :
# MR-APSS: beta =  -0.0536 , beta.se =  0.0596 , p-value =  3.6772e-01 .
# Total NO. of IVs=  41 , NO. of valid IVs with foreground signals:  40.98521 .
# ***********************************************************
# Pair:  ASD ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Alcohol :
# MR-APSS: beta =  0.0038 , beta.se =  0.0333 , p-value =  9.0987e-01 .
# Total NO. of IVs=  41 , NO. of valid IVs with foreground signals:  40.99235 .
# ***********************************************************
# Pair:  ASD ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  BMI :
# MR-APSS: beta =  -0.0077 , beta.se =  0.0527 , p-value =  8.8415e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.97725 .
# ***********************************************************
# Pair:  ASD ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Depression :
# MR-APSS: beta =  0.0502 , beta.se =  0.0434 , p-value =  2.4656e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  30.08095 .
# ***********************************************************
# Pair:  ASD ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  IBD :
# MR-APSS: beta =  -0.0541 , beta.se =  0.0909 , p-value =  5.5179e-01 .
# Total NO. of IVs=  38 , NO. of valid IVs with foreground signals:  37.97736 .
# ***********************************************************
# Pair:  ASD ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  MDD :
# MR-APSS: beta =  0.0144 , beta.se =  0.0364 , p-value =  6.9288e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.99395 .
# ***********************************************************
# Pair:  ASD ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  SCZ :
# MR-APSS: beta =  0.0725 , beta.se =  0.0784 , p-value =  3.5518e-01 .
# Total NO. of IVs=  41 , NO. of valid IVs with foreground signals:  40.9919 .
# ***********************************************************
# Pair:  ASD ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Angina :
# MR-APSS: beta =  -0.023 , beta.se =  0.0372 , p-value =  5.3620e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.99038 .
# ***********************************************************
# Pair:  ASD ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  CAD :
# MR-APSS: beta =  -0.0218 , beta.se =  0.042 , p-value =  6.0288e-01 .
# Total NO. of IVs=  41 , NO. of valid IVs with foreground signals:  40.98869 .
# ***********************************************************
# Pair:  ASD ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  HBP :
# MR-APSS: beta =  -0.0558 , beta.se =  0.0451 , p-value =  2.1612e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.99269 .
# ***********************************************************
# Pair:  ASD ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Income :
# MR-APSS: beta =  -0.0395 , beta.se =  0.0381 , p-value =  3.0005e-01 .
# Total NO. of IVs=  41 , NO. of valid IVs with foreground signals:  40.9869 .
# ***********************************************************
# Pair:  ASD ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  NEB :
# MR-APSS: beta =  0.0045 , beta.se =  0.0281 , p-value =  8.7166e-01 .
# Total NO. of IVs=  35 , NO. of valid IVs with foreground signals:  34.99334 .
# ***********************************************************
# Pair:  ASD ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Smoking :
# MR-APSS: beta =  0.0775 , beta.se =  0.0545 , p-value =  1.5511e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  38.98693 .
# ***********************************************************
# Pair:  ASD ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Urate :
# MR-APSS: beta =  0.0482 , beta.se =  0.0469 , p-value =  3.0374e-01 .
# Total NO. of IVs=  35 , NO. of valid IVs with foreground signals:  34.99342 .
# ***********************************************************
# Pair:  ASD ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Anorexia :
# MR-APSS: beta =  -0.275 , beta.se =  0.186 , p-value =  1.3932e-01 .
# Total NO. of IVs=  35 , NO. of valid IVs with foreground signals:  4.564259 .
# ***********************************************************
# Pair:  ASD ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  CD :
# MR-APSS: beta =  0.0595 , beta.se =  0.1164 , p-value =  6.0964e-01 .
# Total NO. of IVs=  38 , NO. of valid IVs with foreground signals:  37.98361 .
# ***********************************************************
# Pair:  ASD ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Height_GIANT :
# MR-APSS: beta =  0.089 , beta.se =  0.0537 , p-value =  9.7069e-02 .
# Total NO. of IVs=  35 , NO. of valid IVs with foreground signals:  34.99446 .
# ***********************************************************
# Pair:  ASD ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Insomnia :
# MR-APSS: beta =  -0.0272 , beta.se =  0.041 , p-value =  5.0793e-01 .
# Total NO. of IVs=  40 , NO. of valid IVs with foreground signals:  39.98651 .
# ***********************************************************
# Pair:  ASD ~ Neuroticism
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  Neuroticism :
# MR-APSS: beta =  0.0525 , beta.se =  0.0902 , p-value =  5.6047e-01 .
# Total NO. of IVs=  39 , NO. of valid IVs with foreground signals:  14.29352 .
# ***********************************************************
# Pair:  ASD ~ SWB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  ASD  on  SWB :
# MR-APSS: beta =  -0.0751 , beta.se =  0.0383 , p-value =  5.0194e-02 .
# Total NO. of IVs=  35 , NO. of valid IVs with foreground signals:  34.99272 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ AD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  AD :
# MR-APSS: beta =  -0.0176 , beta.se =  0.0999 , p-value =  8.5979e-01 .
# Total NO. of IVs=  248 , NO. of valid IVs with foreground signals:  72.26229 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ ASD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  ASD :
# MR-APSS: beta =  -0.3362 , beta.se =  0.2281 , p-value =  1.4045e-01 .
# Total NO. of IVs=  248 , NO. of valid IVs with foreground signals:  75.04896 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Height_UKB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Height_UKB :
# MR-APSS: beta =  0.2132 , beta.se =  0.1532 , p-value =  1.6405e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  63.64524 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Intelligence
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Intelligence :
# MR-APSS: beta =  0.0852 , beta.se =  0.1186 , p-value =  4.7254e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  77.1203 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  RA :
# MR-APSS: beta =  0.0939 , beta.se =  0.0967 , p-value =  3.3120e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  69.05547 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  T2D :
# MR-APSS: beta =  0.0663 , beta.se =  0.1036 , p-value =  5.2196e-01 .
# Total NO. of IVs=  248 , NO. of valid IVs with foreground signals:  65.08714 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Alcohol :
# MR-APSS: beta =  -0.1066 , beta.se =  0.0938 , p-value =  2.5576e-01 .
# Total NO. of IVs=  249 , NO. of valid IVs with foreground signals:  62.92195 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  BMI :
# MR-APSS: beta =  0.288 , beta.se =  0.1261 , p-value =  2.2359e-02 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  62.60258 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Depression :
# MR-APSS: beta =  0.0509 , beta.se =  0.0582 , p-value =  3.8108e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  69.10102 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  IBD :
# MR-APSS: beta =  -0.0386 , beta.se =  0.1517 , p-value =  7.9921e-01 .
# Total NO. of IVs=  241 , NO. of valid IVs with foreground signals:  59.66146 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  MDD :
# MR-APSS: beta =  -0.0199 , beta.se =  0.056 , p-value =  7.2228e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  78.81413 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  SCZ :
# MR-APSS: beta =  0.2204 , beta.se =  0.1489 , p-value =  1.3872e-01 .
# Total NO. of IVs=  245 , NO. of valid IVs with foreground signals:  94.52319 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Angina :
# MR-APSS: beta =  0.0807 , beta.se =  0.0464 , p-value =  8.1910e-02 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  69.71017 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  CAD :
# MR-APSS: beta =  0.1193 , beta.se =  0.0631 , p-value =  5.8511e-02 .
# Total NO. of IVs=  249 , NO. of valid IVs with foreground signals:  68.12798 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  HBP :
# MR-APSS: beta =  0.0909 , beta.se =  0.0689 , p-value =  1.8711e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  71.86232 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Income :
# MR-APSS: beta =  0.0391 , beta.se =  0.0749 , p-value =  6.0159e-01 .
# Total NO. of IVs=  249 , NO. of valid IVs with foreground signals:  71.31906 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  NEB :
# MR-APSS: beta =  0.0201 , beta.se =  0.0537 , p-value =  7.0804e-01 .
# Total NO. of IVs=  241 , NO. of valid IVs with foreground signals:  69.02537 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Smoking :
# MR-APSS: beta =  0.018 , beta.se =  0.0741 , p-value =  8.0833e-01 .
# Total NO. of IVs=  248 , NO. of valid IVs with foreground signals:  74.93388 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Urate :
# MR-APSS: beta =  0.2507 , beta.se =  0.1134 , p-value =  2.6986e-02 .
# Total NO. of IVs=  242 , NO. of valid IVs with foreground signals:  62.02157 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Anorexia :
# MR-APSS: beta =  0.0384 , beta.se =  0.1163 , p-value =  7.4115e-01 .
# Total NO. of IVs=  221 , NO. of valid IVs with foreground signals:  62.68828 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  CD :
# MR-APSS: beta =  -0.1457 , beta.se =  0.2024 , p-value =  4.7137e-01 .
# Total NO. of IVs=  241 , NO. of valid IVs with foreground signals:  57.28221 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Height_GIANT :
# MR-APSS: beta =  0.2123 , beta.se =  0.1314 , p-value =  1.0614e-01 .
# Total NO. of IVs=  240 , NO. of valid IVs with foreground signals:  59.03651 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Insomnia :
# MR-APSS: beta =  0.1932 , beta.se =  0.0734 , p-value =  8.4763e-03 .
# Total NO. of IVs=  249 , NO. of valid IVs with foreground signals:  73.27844 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ Neuroticism
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  Neuroticism :
# MR-APSS: beta =  0.0748 , beta.se =  0.0869 , p-value =  3.8942e-01 .
# Total NO. of IVs=  243 , NO. of valid IVs with foreground signals:  71.60473 .
# ***********************************************************
# Pair:  Daytime_Sleepiness ~ SWB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Daytime_Sleepiness  on  SWB :
# MR-APSS: beta =  -0.0222 , beta.se =  0.0508 , p-value =  6.6207e-01 .
# Total NO. of IVs=  242 , NO. of valid IVs with foreground signals:  69.17492 .
# ***********************************************************
# Pair:  Height_UKB ~ AD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  AD :
# MR-APSS: beta =  -0.0423 , beta.se =  0.0149 , p-value =  4.4081e-03 .
# Total NO. of IVs=  2217 , NO. of valid IVs with foreground signals:  394.3933 .
# ***********************************************************
# Pair:  Height_UKB ~ ASD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  ASD :
# MR-APSS: beta =  0.0124 , beta.se =  0.0238 , p-value =  6.0224e-01 .
# Total NO. of IVs=  2220 , NO. of valid IVs with foreground signals:  387.8746 .
# ***********************************************************
# Pair:  Height_UKB ~ Daytime_Sleepiness
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Daytime_Sleepiness :
# MR-APSS: beta =  -0.0031 , beta.se =  0.0058 , p-value =  5.9422e-01 .
# Total NO. of IVs=  2226 , NO. of valid IVs with foreground signals:  395.3283 .
# ***********************************************************
# Pair:  Height_UKB ~ Intelligence
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Intelligence :
# MR-APSS: beta =  0.0741 , beta.se =  0.013 , p-value =  1.3414e-08 .
# Total NO. of IVs=  2227 , NO. of valid IVs with foreground signals:  393.1643 .
# ***********************************************************
# Pair:  Height_UKB ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  RA :
# MR-APSS: beta =  0.0434 , beta.se =  0.0156 , p-value =  5.4557e-03 .
# Total NO. of IVs=  2224 , NO. of valid IVs with foreground signals:  397.4994 .
# ***********************************************************
# Pair:  Height_UKB ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  T2D :
# MR-APSS: beta =  -0.0083 , beta.se =  0.0143 , p-value =  5.6033e-01 .
# Total NO. of IVs=  2218 , NO. of valid IVs with foreground signals:  403.5913 .
# ***********************************************************
# Pair:  Height_UKB ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Alcohol :
# MR-APSS: beta =  0.0159 , beta.se =  0.0078 , p-value =  4.1325e-02 .
# Total NO. of IVs=  2225 , NO. of valid IVs with foreground signals:  390.1198 .
# ***********************************************************
# Pair:  Height_UKB ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  BMI :
# MR-APSS: beta =  -0.0637 , beta.se =  0.0135 , p-value =  2.4801e-06 .
# Total NO. of IVs=  2226 , NO. of valid IVs with foreground signals:  405.4622 .
# ***********************************************************
# Pair:  Height_UKB ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Depression :
# MR-APSS: beta =  -0.0122 , beta.se =  0.0056 , p-value =  2.9436e-02 .
# Total NO. of IVs=  2223 , NO. of valid IVs with foreground signals:  394.3694 .
# ***********************************************************
# Pair:  Height_UKB ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  IBD :
# MR-APSS: beta =  0.0319 , beta.se =  0.0197 , p-value =  1.0478e-01 .
# Total NO. of IVs=  2224 , NO. of valid IVs with foreground signals:  399.6071 .
# ***********************************************************
# Pair:  Height_UKB ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  MDD :
# MR-APSS: beta =  7e-04 , beta.se =  0.0059 , p-value =  9.0627e-01 .
# Total NO. of IVs=  2227 , NO. of valid IVs with foreground signals:  393.867 .
# ***********************************************************
# Pair:  Height_UKB ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  SCZ :
# MR-APSS: beta =  -0.0147 , beta.se =  0.0144 , p-value =  3.0679e-01 .
# Total NO. of IVs=  2185 , NO. of valid IVs with foreground signals:  387.4595 .
# ***********************************************************
# Pair:  Height_UKB ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Angina :
# MR-APSS: beta =  -0.0301 , beta.se =  0.0073 , p-value =  3.9853e-05 .
# Total NO. of IVs=  2227 , NO. of valid IVs with foreground signals:  400.5705 .
# ***********************************************************
# Pair:  Height_UKB ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  CAD :
# MR-APSS: beta =  -0.057 , beta.se =  0.0106 , p-value =  7.3636e-08 .
# Total NO. of IVs=  2224 , NO. of valid IVs with foreground signals:  396.5718 .
# ***********************************************************
# Pair:  Height_UKB ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  HBP :
# MR-APSS: beta =  -0.031 , beta.se =  0.011 , p-value =  4.8120e-03 .
# Total NO. of IVs=  2227 , NO. of valid IVs with foreground signals:  413.7424 .
# ***********************************************************
# Pair:  Height_UKB ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Income :
# MR-APSS: beta =  0.0543 , beta.se =  0.0077 , p-value =  1.6180e-12 .
# Total NO. of IVs=  2226 , NO. of valid IVs with foreground signals:  395.2777 .
# ***********************************************************
# Pair:  Height_UKB ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  NEB :
# MR-APSS: beta =  0.001 , beta.se =  0.0056 , p-value =  8.5618e-01 .
# Total NO. of IVs=  2187 , NO. of valid IVs with foreground signals:  385.1921 .
# ***********************************************************
# Pair:  Height_UKB ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Smoking :
# MR-APSS: beta =  -0.0037 , beta.se =  0.0068 , p-value =  5.8862e-01 .
# Total NO. of IVs=  2208 , NO. of valid IVs with foreground signals:  382.5819 .
# ***********************************************************
# Pair:  Height_UKB ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Urate :
# MR-APSS: beta =  0 , beta.se =  0.002 , p-value =  9.8785e-01 .
# Total NO. of IVs=  2199 , NO. of valid IVs with foreground signals:  386.6527 .
# ***********************************************************
# Pair:  Height_UKB ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Anorexia :
# MR-APSS: beta =  0.0123 , beta.se =  0.0129 , p-value =  3.3995e-01 .
# Total NO. of IVs=  2077 , NO. of valid IVs with foreground signals:  347.0775 .
# ***********************************************************
# Pair:  Height_UKB ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  CD :
# MR-APSS: beta =  0.0203 , beta.se =  0.024 , p-value =  3.9864e-01 .
# Total NO. of IVs=  2224 , NO. of valid IVs with foreground signals:  398.9499 .
# ***********************************************************
# Pair:  Height_UKB ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Height_GIANT :
# MR-APSS: beta =  0.8087 , beta.se =  0.0233 , p-value =  3.8481e-264 .
# Total NO. of IVs=  2176 , NO. of valid IVs with foreground signals:  396.9522 .
# ***********************************************************
# Pair:  Height_UKB ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Insomnia :
# MR-APSS: beta =  -0.0148 , beta.se =  0.0066 , p-value =  2.4493e-02 .
# Total NO. of IVs=  2226 , NO. of valid IVs with foreground signals:  394.8063 .
# ***********************************************************
# Pair:  Height_UKB ~ Neuroticism
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  Neuroticism :
# MR-APSS: beta =  -0.0114 , beta.se =  0.0078 , p-value =  1.4150e-01 .
# Total NO. of IVs=  2227 , NO. of valid IVs with foreground signals:  396.4799 .
# ***********************************************************
# Pair:  Height_UKB ~ SWB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Height_UKB  on  SWB :
# MR-APSS: beta =  -0.0045 , beta.se =  0.006 , p-value =  4.5485e-01 .
# Total NO. of IVs=  2188 , NO. of valid IVs with foreground signals:  381.1223 .
# ***********************************************************
# Pair:  Intelligence ~ AD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  AD :
# MR-APSS: beta =  -0.132 , beta.se =  0.0781 , p-value =  9.1069e-02 .
# Total NO. of IVs=  402 , NO. of valid IVs with foreground signals:  68.47134 .
# ***********************************************************
# Pair:  Intelligence ~ ASD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  ASD :
# MR-APSS: beta =  0.2629 , beta.se =  0.1392 , p-value =  5.8973e-02 .
# Total NO. of IVs=  400 , NO. of valid IVs with foreground signals:  64.49809 .
# ***********************************************************
# Pair:  Intelligence ~ Daytime_Sleepiness
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Daytime_Sleepiness :
# MR-APSS: beta =  -0.0476 , beta.se =  0.0377 , p-value =  2.0658e-01 .
# Total NO. of IVs=  400 , NO. of valid IVs with foreground signals:  73.16991 .
# ***********************************************************
# Pair:  Intelligence ~ Height_UKB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Height_UKB :
# MR-APSS: beta =  0.3158 , beta.se =  0.1162 , p-value =  6.5739e-03 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  55.59181 .
# ***********************************************************
# Pair:  Intelligence ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  RA :
# MR-APSS: beta =  -0.2003 , beta.se =  0.0745 , p-value =  7.1698e-03 .
# Total NO. of IVs=  401 , NO. of valid IVs with foreground signals:  74.34622 .
# ***********************************************************
# Pair:  Intelligence ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  T2D :
# MR-APSS: beta =  -0.0388 , beta.se =  0.0751 , p-value =  6.0590e-01 .
# Total NO. of IVs=  398 , NO. of valid IVs with foreground signals:  67.5893 .
# ***********************************************************
# Pair:  Intelligence ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Alcohol :
# MR-APSS: beta =  0.0738 , beta.se =  0.0497 , p-value =  1.3745e-01 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  68.69851 .
# ***********************************************************
# Pair:  Intelligence ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  BMI :
# MR-APSS: beta =  -0.1521 , beta.se =  0.0813 , p-value =  6.1363e-02 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  73.14071 .
# ***********************************************************
# Pair:  Intelligence ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Depression :
# MR-APSS: beta =  -0.1037 , beta.se =  0.0332 , p-value =  1.7773e-03 .
# Total NO. of IVs=  400 , NO. of valid IVs with foreground signals:  78.37219 .
# ***********************************************************
# Pair:  Intelligence ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  IBD :
# MR-APSS: beta =  0.0408 , beta.se =  0.1023 , p-value =  6.9012e-01 .
# Total NO. of IVs=  402 , NO. of valid IVs with foreground signals:  56.01873 .
# ***********************************************************
# Pair:  Intelligence ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  MDD :
# MR-APSS: beta =  0.0225 , beta.se =  0.0351 , p-value =  5.2168e-01 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  76.48664 .
# ***********************************************************
# Pair:  Intelligence ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  SCZ :
# MR-APSS: beta =  -0.3238 , beta.se =  0.1043 , p-value =  1.9152e-03 .
# Total NO. of IVs=  391 , NO. of valid IVs with foreground signals:  78.86244 .
# ***********************************************************
# Pair:  Intelligence ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Angina :
# MR-APSS: beta =  -0.0538 , beta.se =  0.0279 , p-value =  5.3997e-02 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  70.3657 .
# ***********************************************************
# Pair:  Intelligence ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  CAD :
# MR-APSS: beta =  -0.0966 , beta.se =  0.0384 , p-value =  1.1915e-02 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  70.0773 .
# ***********************************************************
# Pair:  Intelligence ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  HBP :
# MR-APSS: beta =  -0.0261 , beta.se =  0.0476 , p-value =  5.8362e-01 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  65.09508 .
# ***********************************************************
# Pair:  Intelligence ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Income :
# MR-APSS: beta =  0.3553 , beta.se =  0.0594 , p-value =  2.2285e-09 .
# Total NO. of IVs=  403 , NO. of valid IVs with foreground signals:  62.32222 .
# ***********************************************************
# Pair:  Intelligence ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  NEB :
# MR-APSS: beta =  -0.0579 , beta.se =  0.0332 , p-value =  8.0849e-02 .
# Total NO. of IVs=  385 , NO. of valid IVs with foreground signals:  71.57483 .
# ***********************************************************
# Pair:  Intelligence ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Smoking :
# MR-APSS: beta =  -0.0762 , beta.se =  0.0435 , p-value =  7.9629e-02 .
# Total NO. of IVs=  398 , NO. of valid IVs with foreground signals:  79.91094 .
# ***********************************************************
# Pair:  Intelligence ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Urate :
# MR-APSS: beta =  -0.0049 , beta.se =  0.0527 , p-value =  9.2658e-01 .
# Total NO. of IVs=  386 , NO. of valid IVs with foreground signals:  65.97606 .
# ***********************************************************
# Pair:  Intelligence ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Anorexia :
# MR-APSS: beta =  0.1965 , beta.se =  0.0895 , p-value =  2.8216e-02 .
# Total NO. of IVs=  365 , NO. of valid IVs with foreground signals:  68.22473 .
# ***********************************************************
# Pair:  Intelligence ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  CD :
# MR-APSS: beta =  0.0725 , beta.se =  0.1304 , p-value =  5.7858e-01 .
# Total NO. of IVs=  402 , NO. of valid IVs with foreground signals:  53.93816 .
# ***********************************************************
# Pair:  Intelligence ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Height_GIANT :
# MR-APSS: beta =  0.161 , beta.se =  0.1052 , p-value =  1.2577e-01 .
# Total NO. of IVs=  383 , NO. of valid IVs with foreground signals:  47.06809 .
# ***********************************************************
# Pair:  Intelligence ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Intelligence  on  Insomnia :
# MR-APSS: beta =  -0.0492 , beta.se =  0.0393 , p-value =  2.1088e-01 .
# Total NO. of IVs=  400 , NO. of valid IVs with foreground signals:  87.20293 .
# ...
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  153.1441 .
# ***********************************************************
# Pair:  Neuroticism ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Depression :
# MR-APSS: beta =  0.5086 , beta.se =  0.0485 , p-value =  9.1856e-26 .
# Total NO. of IVs=  462 , NO. of valid IVs with foreground signals:  137.3705 .
# ***********************************************************
# Pair:  Neuroticism ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  IBD :
# MR-APSS: beta =  -0.1275 , beta.se =  0.1096 , p-value =  2.4481e-01 .
# Total NO. of IVs=  461 , NO. of valid IVs with foreground signals:  113.3155 .
# ***********************************************************
# Pair:  Neuroticism ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  MDD :
# MR-APSS: beta =  0.1757 , beta.se =  0.0413 , p-value =  2.0569e-05 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  150.6083 .
# ***********************************************************
# Pair:  Neuroticism ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  SCZ :
# MR-APSS: beta =  0.5708 , beta.se =  0.1151 , p-value =  7.0239e-07 .
# Total NO. of IVs=  457 , NO. of valid IVs with foreground signals:  122.8707 .
# ***********************************************************
# Pair:  Neuroticism ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Angina :
# MR-APSS: beta =  0.0958 , beta.se =  0.0332 , p-value =  3.9070e-03 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  146.9606 .
# ***********************************************************
# Pair:  Neuroticism ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  CAD :
# MR-APSS: beta =  0.0318 , beta.se =  0.0524 , p-value =  5.4391e-01 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  133.5902 .
# ***********************************************************
# Pair:  Neuroticism ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  HBP :
# MR-APSS: beta =  -0.0315 , beta.se =  0.0627 , p-value =  6.1470e-01 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  120.0115 .
# ***********************************************************
# Pair:  Neuroticism ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Income :
# MR-APSS: beta =  -0.2217 , beta.se =  0.0571 , p-value =  1.0445e-04 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  133.7061 .
# ***********************************************************
# Pair:  Neuroticism ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  NEB :
# MR-APSS: beta =  0.0051 , beta.se =  0.0342 , p-value =  8.8211e-01 .
# Total NO. of IVs=  447 , NO. of valid IVs with foreground signals:  143.8767 .
# ***********************************************************
# Pair:  Neuroticism ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Smoking :
# MR-APSS: beta =  0.1134 , beta.se =  0.0516 , p-value =  2.7872e-02 .
# Total NO. of IVs=  454 , NO. of valid IVs with foreground signals:  150.127 .
# ***********************************************************
# Pair:  Neuroticism ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Urate :
# MR-APSS: beta =  -0.0299 , beta.se =  0.0557 , p-value =  5.9101e-01 .
# Total NO. of IVs=  450 , NO. of valid IVs with foreground signals:  146.6474 .
# ***********************************************************
# Pair:  Neuroticism ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Anorexia :
# MR-APSS: beta =  0.4004 , beta.se =  0.0807 , p-value =  6.9010e-07 .
# Total NO. of IVs=  430 , NO. of valid IVs with foreground signals:  155.2941 .
# ***********************************************************
# Pair:  Neuroticism ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  CD :
# MR-APSS: beta =  -0.2209 , beta.se =  0.1294 , p-value =  8.7719e-02 .
# Total NO. of IVs=  461 , NO. of valid IVs with foreground signals:  123.2826 .
# ***********************************************************
# Pair:  Neuroticism ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Height_GIANT :
# MR-APSS: beta =  -0.1337 , beta.se =  0.0754 , p-value =  7.6346e-02 .
# Total NO. of IVs=  443 , NO. of valid IVs with foreground signals:  114.3406 .
# ***********************************************************
# Pair:  Neuroticism ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  Insomnia :
# MR-APSS: beta =  0.2948 , beta.se =  0.0467 , p-value =  2.7001e-10 .
# Total NO. of IVs=  463 , NO. of valid IVs with foreground signals:  141.0674 .
# ***********************************************************
# Pair:  Neuroticism ~ SWB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  Neuroticism  on  SWB :
# MR-APSS: beta =  -0.23 , beta.se =  0.0393 , p-value =  5.0462e-09 .
# Total NO. of IVs=  450 , NO. of valid IVs with foreground signals:  140.6947 .
# ***********************************************************
# Pair:  SWB ~ AD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  AD :
# MR-APSS: beta =  -0.1675 , beta.se =  0.7043 , p-value =  8.1200e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  11.9378 .
# ***********************************************************
# Pair:  SWB ~ ASD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  ASD :
# MR-APSS: beta =  -0.9431 , beta.se =  0.9783 , p-value =  3.3508e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  5.636613 .
# ***********************************************************
# Pair:  SWB ~ Daytime_Sleepiness
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Daytime_Sleepiness :
# MR-APSS: beta =  -0.1103 , beta.se =  0.3353 , p-value =  7.4232e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  6.765954 .
# ***********************************************************
# Pair:  SWB ~ Height_UKB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Height_UKB :
# MR-APSS: beta =  -2.7013 , beta.se =  1.8558 , p-value =  1.4552e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  1.212259 .
# ***********************************************************
# Pair:  SWB ~ Intelligence
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Intelligence :
# MR-APSS: beta =  -0.076 , beta.se =  0.5171 , p-value =  8.8313e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  7.115277 .
# ***********************************************************
# Pair:  SWB ~ RA
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  RA :
# MR-APSS: beta =  -0.3805 , beta.se =  0.6887 , p-value =  5.8055e-01 .
# Total NO. of IVs=  64 , NO. of valid IVs with foreground signals:  10.44736 .
# ***********************************************************
# Pair:  SWB ~ T2D
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  T2D :
# MR-APSS: beta =  -2.2999 , beta.se =  1.4661 , p-value =  1.1671e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  1.154669 .
# ***********************************************************
# Pair:  SWB ~ Alcohol
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Alcohol :
# MR-APSS: beta =  -8.7657 , beta.se =  12.3115 , p-value =  4.7647e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  5.939245 .
# ***********************************************************
# Pair:  SWB ~ BMI
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  BMI :
# MR-APSS: beta =  1.6433 , beta.se =  1.1174 , p-value =  1.4138e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  11.81909 .
# ***********************************************************
# Pair:  SWB ~ Depression
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Depression :
# MR-APSS: beta =  -1.4178 , beta.se =  0.8901 , p-value =  1.1119e-01 .
# Total NO. of IVs=  64 , NO. of valid IVs with foreground signals:  3.040341 .
# ***********************************************************
# Pair:  SWB ~ IBD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  IBD :
# MR-APSS: beta =  0.0474 , beta.se =  0.6296 , p-value =  9.4002e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  7.533886 .
# ***********************************************************
# Pair:  SWB ~ MDD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  MDD :
# MR-APSS: beta =  -0.3235 , beta.se =  0.4205 , p-value =  4.4162e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  9.266651 .
# ***********************************************************
# Pair:  SWB ~ SCZ
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  SCZ :
# MR-APSS: beta =  -0.3742 , beta.se =  0.5703 , p-value =  5.1171e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  7.798626 .
# ***********************************************************
# Pair:  SWB ~ Angina
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Angina :
# MR-APSS: beta =  -0.0227 , beta.se =  0.2817 , p-value =  9.3588e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  8.447758 .
# ***********************************************************
# Pair:  SWB ~ CAD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  CAD :
# MR-APSS: beta =  0.1165 , beta.se =  0.2854 , p-value =  6.8319e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  8.59457 .
# ***********************************************************
# Pair:  SWB ~ HBP
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  HBP :
# MR-APSS: beta =  0.5916 , beta.se =  0.4732 , p-value =  2.1123e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  5.362534 .
# ***********************************************************
# Pair:  SWB ~ Income
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Income :
# MR-APSS: beta =  5.2565 , beta.se =  4.7429 , p-value =  2.6774e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  65.98627 .
# ***********************************************************
# Pair:  SWB ~ NEB
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  NEB :
# MR-APSS: beta =  -0.0013 , beta.se =  0.1363 , p-value =  9.9225e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  7.289643 .
# ***********************************************************
# Pair:  SWB ~ Smoking
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Smoking :
# MR-APSS: beta =  0.4109 , beta.se =  0.5814 , p-value =  4.7978e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  14.57048 .
# ***********************************************************
# Pair:  SWB ~ Urate
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Urate :
# MR-APSS: beta =  0.2611 , beta.se =  0.3765 , p-value =  4.8798e-01 .
# Total NO. of IVs=  66 , NO. of valid IVs with foreground signals:  8.380742 .
# ***********************************************************
# Pair:  SWB ~ Anorexia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Anorexia :
# MR-APSS: beta =  -0.9625 , beta.se =  0.4346 , p-value =  2.6773e-02 .
# Total NO. of IVs=  57 , NO. of valid IVs with foreground signals:  10.06635 .
# ***********************************************************
# Pair:  SWB ~ CD
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  CD :
# MR-APSS: beta =  -0.0858 , beta.se =  0.8007 , p-value =  9.1466e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  7.058192 .
# ***********************************************************
# Pair:  SWB ~ Height_GIANT
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Height_GIANT :
# MR-APSS: beta =  1.6141 , beta.se =  1.7595 , p-value =  3.5896e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  3.281521 .
# ***********************************************************
# Pair:  SWB ~ Insomnia
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Insomnia :
# MR-APSS: beta =  -0.4026 , beta.se =  0.2239 , p-value =  7.2138e-02 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  10.16022 .
# ***********************************************************
# Pair:  SWB ~ Neuroticism
# Run MR-APSS ...
# IV selection threshold: 5e-05
# ***********************************************************
# MR test results of  SWB  on  Neuroticism :
# MR-APSS: beta =  -1.6633 , beta.se =  1.0139 , p-value =  1.0089e-01 .
# Total NO. of IVs=  65 , NO. of valid IVs with foreground signals:  3.740949 .
# ***********************************************************
#      user    system   elapsed
# 25142.961  6163.566 17961.738

# %%
apss_res = read.table("Traits_MRAPSS.MRres", header = F)
colnames(apss_res) = c("exposure","outcome", "nsnp","pi","nvalid","sigma.sq","tau.sq","b","se","pval",
                        "Method", "cor.Threshold", "IVstrength", "Threshold")
write.table(apss_res, "Traits_MRAPSS.MRres", quote=F, col.names = T, append = F,row.names = F)
